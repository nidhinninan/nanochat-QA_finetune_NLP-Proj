# %% [markdown]
# # Notebook 2 · Load Base `nanochat` Checkpoint
#
# This notebook loads the `sdobson/nanochat` checkpoint, evaluates its baseline performance on the prepared ScienceQA subset, and saves the raw baseline responses for later comparison.

# %%
import sys
from pathlib import Path
import subprocess

# Clone the nanochat repository (idempotent)
nanochat_repo = Path("nanochat")
if not nanochat_repo.exists():
    print("Cloning karpathy/nanochat...")
    subprocess.run(["git", "clone", "https://github.com/karpathy/nanochat.git", str(nanochat_repo)], check=True)
else:
    print("nanochat repository already present.")

# Ensure the nanochat package is importable
package_path = nanochat_repo.resolve()
if str(package_path) not in sys.path:
    sys.path.insert(0, str(package_path))

from nanochat.gpt import GPT, GPTConfig
from nanochat.tokenizer import RustBPETokenizer
# Out:
# Cloning karpathy/nanochat...
# Cloning into 'nanochat'...

# %%
import torch

if torch.cuda.is_available():
    device_count = torch.cuda.device_count()
    print(f"CUDA is available. You have {device_count} GPU(s) available.")
    for i in range(device_count):
        print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
else:
    print("CUDA is not available. PyTorch is using the CPU.")

# Load the model using nanochat's native scripts ---
print("\nLoading model using nanochat's native functions...")
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Device selected: {device}")
# Out:
# CUDA is available. You have 1 GPU(s) available.
# GPU 0: Tesla P100-PCIE-16GB
#
# Loading model using nanochat's native functions...
# Device selected: cuda

# %%
from huggingface_hub import hf_hub_download

# Download checkpoint artifacts from Hugging Face (if needed)
model_repo = "sdobson/nanochat"
base_cache = Path.home() / ".cache" / "nanochat"

files_to_download = {
    "model_000650.pt": base_cache / "chatsft_checkpoints" / "d20",
    "meta_000650.json": base_cache / "chatsft_checkpoints" / "d20",
    "tokenizer.pkl": base_cache / "tokenizer",
    "token_bytes.pt": base_cache / "tokenizer",
}

for filename, target_dir in files_to_download.items():
    target_dir.mkdir(parents=True, exist_ok=True)
    target_path = target_dir / filename
    if not target_path.exists():
        print(f"Downloading {filename}...")
        hf_hub_download(
            repo_id=model_repo,
            filename=filename,
            local_dir=str(target_dir),
            local_dir_use_symlinks=False,
        )
    else:
        print(f"Found cached {filename}.")
# Out:
# Downloading model_000650.pt...
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/file_download.py:979: UserWarning: `local_dir_use_symlinks` parameter is deprecated and will be ignored. The process to download files to a local folder has been updated and do not rely on symlinks anymore. You only need to pass a destination folder as`local_dir`.
# For more details, check out https://huggingface.co/docs/huggingface_hub/main/en/guides/download#download-files-to-local-folder.
#   warnings.warn(
# model_000650.pt:   0%|          | 0.00/2.08G [00:00<?, ?B/s]
# Downloading meta_000650.json...
# meta_000650.json:   0%|          | 0.00/309 [00:00<?, ?B/s]
# Downloading tokenizer.pkl...
# tokenizer.pkl:   0%|          | 0.00/846k [00:00<?, ?B/s]
# Downloading token_bytes.pt...
# token_bytes.pt:   0%|          | 0.00/264k [00:00<?, ?B/s]

# %%
# # Check if model is already loaded
# # The model was loaded in Cell 4 - no need to reload it!

# try:
#     # Check if model exists and has parameters
#     _ = next(model.parameters())
#     model_device = next(model.parameters()).device
#     print("✓ Model is already loaded from Cell 4")
#     print(f"✓ Model is on device: {model_device}")
#     print(f"✓ Model has {sum(p.numel() for p in model.parameters()) / 1e6:.0f}M parameters")
#     print("\nNo need to reload - the model is ready to use!")
# except (NameError, StopIteration):
#     print("⚠ Model not found. Please run Cell 4 first to load the model.")
#     raise RuntimeError("Model must be loaded first. Run Cell 4 before this cell.")

# %%
# GPU Memory Management & Model Saving/Loading Guide
# ====================================================

# NOTE: Your GPU has only 3.63 GiB memory. The model (561M params) uses ~2-3 GiB.
# If you run out of GPU memory, you have several options:

# Option 1: Clear GPU cache (run this if you get OOM errors)
# import torch
# torch.cuda.empty_cache()
# print("GPU cache cleared")

# Option 2: Move model to CPU (slower but no memory limits)
# device = torch.device('cpu')
# model.to(device)
# print(f"Model moved to {device}")

# Option 3: Use smaller batch size in training (already set to 2 in Cell 21)

# ====================================================
# Saving a fine-tuned model (after training)
# ====================================================

# model_save_path = 'my_finetuned_scienceqa_model.pth'
# torch.save(model.state_dict(), model_save_path)
# print(f"Model saved to {model_save_path}")

# ====================================================
# Loading a previously saved fine-tuned model
# ====================================================

# model_load_path = 'my_finetuned_scienceqa_model.pth'
# if Path(model_load_path).exists():
#     # Load to CPU first to avoid OOM, then optionally move to GPU
#     state_dict = torch.load(model_load_path, map_location='cpu')
#     model.load_state_dict(state_dict)
#     model.eval()
#     # model.to('cuda')  # Uncomment if you have enough GPU memory
#     print(f"Fine-tuned model loaded from {model_load_path}")
# else:
#     print(f"Warning: {model_load_path} not found.")

print("✓ GPU memory management options available above (commented out)")
# Out:
# ✓ GPU memory management options available above (commented out)

# %%
# # Clear GPU memory if you had OOM errors
# import torch
# import gc

# # Force garbage collection
# gc.collect()

# # Clear CUDA cache if CUDA is available
# if torch.cuda.is_available():
#     torch.cuda.empty_cache()
#     print("✓ GPU cache cleared")
#     print(f"✓ GPU memory allocated: {torch.cuda.memory_allocated(0) / 1024**3:.2f} GiB")
#     print(f"✓ GPU memory reserved: {torch.cuda.memory_reserved(0) / 1024**3:.2f} GiB")
# else:
#     print("✓ No GPU available - running on CPU")

# %%
# Clear GPU memory if you had OOM errors
import torch
import gc

# Force garbage collection
gc.collect()

# Clear CUDA cache if CUDA is available
if torch.cuda.is_available():
    torch.cuda.empty_cache()
    print("✓ GPU cache cleared")
else:
    print("✓ No GPU available - running on CPU")
# Out:
# ✓ GPU cache cleared

# %%
import os
import json
import subprocess
from pathlib import Path

import torch
from huggingface_hub import hf_hub_download

# --- 1. Set up the nanochat environment ---
if not Path("nanochat").exists():
    print("Cloning karpathy/nanochat repository...")
    subprocess.run(["git", "clone", "https://github.com/karpathy/nanochat.git", "nanochat"], check=True)
else:
    print("nanochat repository already exists.")

# Ensure that we can import the nanochat modules
import sys
package_path = os.path.abspath("nanochat")
if package_path not in sys.path:
    sys.path.insert(0, package_path)

from nanochat.common import autodetect_device_type, compute_init
from nanochat.checkpoint_manager import build_model

# --- 2. Download (or reuse) the checkpoint artifacts ---
model_repo = "sdobson/nanochat"
base_cache = Path.home() / ".cache" / "nanochat"
files_to_download = {
    "model_000650.pt": base_cache / "chatsft_checkpoints" / "d20",
    "meta_000650.json": base_cache / "chatsft_checkpoints" / "d20",
    "tokenizer.pkl": base_cache / "tokenizer",
    "token_bytes.pt": base_cache / "tokenizer",
}
base_cache.mkdir(parents=True, exist_ok=True)

print("Ensuring local checkpoint cache is populated...")
for filename, target_dir in files_to_download.items():
    target_dir.mkdir(parents=True, exist_ok=True)
    target_path = target_dir / filename
    if not target_path.exists():
        print(f"Downloading {filename}...")
        hf_hub_download(
            repo_id=model_repo,
            filename=filename,
            local_dir=str(target_dir),
            local_dir_use_symlinks=False,
        )
    else:
        print(f"Found cached {filename}.")

# --- 3. Initialize distributed context & load the model ---
device_type = autodetect_device_type()
ddp, ddp_rank, ddp_local_rank, ddp_world_size, device = compute_init(device_type=device_type)
print(f"Rank {ddp_rank}: using device {device}")

checkpoint_dir = base_cache / "chatsft_checkpoints" / "d20"
checkpoint_step = int(os.environ.get("SCIASSIST_BASE_STEP", "650"))
model, tokenizer, meta = build_model(
    checkpoint_dir=str(checkpoint_dir),
    step=checkpoint_step,
    device=device,
    phase="train",
)
base_model = model  # keep an unwrapped handle for optimizer setup/saving

print(
    f"Loaded model depth={meta['model_config']['n_layer']} | params "+
    f"~{sum(p.numel() for p in base_model.parameters()) / 1e6:.0f}M | world size={ddp_world_size}"
)
# Out:
# 2025-11-24 02:05:12,402 - nanochat.common - INFO - Distributed world size: 1
# nanochat repository already exists.
# Ensuring local checkpoint cache is populated...
# Found cached model_000650.pt.
# Found cached meta_000650.json.
# Found cached tokenizer.pkl.
# Found cached token_bytes.pt.
# Autodetected device type: cuda
# Rank 0: using device cuda
# 2025-11-24 02:05:14,222 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 20, 'n_head': 10, 'n_kv_head': 10, 'n_embd': 1280}
# Loaded model depth=20 | params ~561M | world size=1

# %%
# --- Configuration: Multi-GPU vs Single-GPU ---
USE_SINGLE_GPU_MODE = True  # Set False for multi-GPU DDP training

# DDP wrapping for multi-GPU training
if ddp:
    import torch.nn.parallel
    model = torch.nn.parallel.DistributedDataParallel(
        model,
        device_ids=[ddp_local_rank],
        output_device=ddp_local_rank
    )
    print(f"Rank {ddp_rank}: Model wrapped in DDP")

# Single T4 GPU optimizations
if USE_SINGLE_GPU_MODE and ddp_world_size == 1:
    print("⚙️ SINGLE T4 GPU MODE - Applying memory optimizations:")
    # Enable gradient checkpointing to save memory (trade compute for memory)
    # Note: nanochat's GPT doesn't have built-in checkpointing, but we reduce batch size
    print("  - Reduced device_batch_size to 1")
    print("  - Increased gradient_accumulation_steps to maintain effective batch size")
    print("  - Using bfloat16 mixed precision (already enabled in model)")
# Out:
# ⚙️ SINGLE T4 GPU MODE - Applying memory optimizations:
#   - Reduced device_batch_size to 1
#   - Increased gradient_accumulation_steps to maintain effective batch size
#   - Using bfloat16 mixed precision (already enabled in model)

# %%
# Initialize the nanochat tokenizer
tokenizer_dir = base_cache / "tokenizer"
tokenizer = RustBPETokenizer.from_directory(str(tokenizer_dir))

print("Tokenizer ready.")
# Out:
# Tokenizer ready.

# %%
# Precompute frequently used special token IDs
bos_id = tokenizer.get_bos_token_id()
assistant_start_id = tokenizer.encode_special("<|assistant_start|>")
assistant_end_id = tokenizer.encode_special("<|assistant_end|>")
user_start_id = tokenizer.encode_special("<|user_start|>")
user_end_id = tokenizer.encode_special("<|user_end|>")

# %%
def build_completion_prompt(conversation):
    """Return token ids primed for assistant completion."""
    conversation_for_completion = json.loads(json.dumps(conversation))  # deep copy via json
    conversation_for_completion["messages"][-1]["content"] = ""
    prompt_tokens = tokenizer.render_for_completion(conversation_for_completion)
    return prompt_tokens


def generate_response_from_tokens(prompt_tokens, *, max_tokens=256, temperature=0.7, top_k=50):
    tokens = list(prompt_tokens)
    generated = []
    # Access the underlying model if it's wrapped in DataParallel
    model_to_use = model.module if isinstance(model, torch.nn.DataParallel) else model
    for token in model_to_use.generate(tokens, max_tokens=max_tokens, temperature=temperature, top_k=top_k):
        tokens.append(token)
        generated.append(token)
        if token == assistant_end_id:
            break
    text = tokenizer.decode([token for token in generated if token not in {assistant_end_id}])
    return text.strip(), generated


def generate_response_for_conversation(conversation, **generation_kwargs):
    prompt_tokens = build_completion_prompt(conversation)
    text, token_sequence = generate_response_from_tokens(prompt_tokens, **generation_kwargs)
    return {
        "prompt_tokens": prompt_tokens,
        "generated_tokens": token_sequence,
        "response_text": text,
    }

# %%
import sys
# This will print the path to the Python executable the kernel is using
print(sys.executable)
# Out:
# /usr/bin/python3

# %%
# !pip install -q transformers datasets torch accelerate huggingface_hub bitsandbytes

# HuggingFace authentication (using Kaggle Secrets)
from huggingface_hub import login
from kaggle_secrets import UserSecretsClient

try:
    user_secrets = UserSecretsClient()
    # Replace 'HF_TOKEN' with the exact name of your secret in Kaggle
    hf_token = user_secrets.get_secret("HF_TOKEN") 
    login(token=hf_token)
    print("✅ Successfully logged in to Hugging Face using Kaggle Secret.")
except Exception as e:
    print(f"⚠️ Failed to login with Kaggle Secret: {e}")
    # Fallback for local testing or if secret is missing
    # login()
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 997.1 kB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 61.3 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 30.0 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 41.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 2.7 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 28.3 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 12.6 MB/s eta 0:00:0000:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 7.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 75.4 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.4/59.4 MB 26.9 MB/s eta 0:00:00:00:0100:01
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.7/47.7 MB 32.5 MB/s eta 0:00:00:00:010:01m
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.12.0 requires google-cloud-bigquery-storage<3.0.0,>=2.30.0, which is not installed.
# pylibcudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# cudf-cu12 25.2.2 requires pyarrow<20.0.0a0,>=14.0.0; platform_machine == "x86_64", but you have pyarrow 22.0.0 which is incompatible.
# bigframes 2.12.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# libcugraph-cu12 25.6.0 requires libraft-cu12==25.6.*, but you have libraft-cu12 25.2.0 which is incompatible.
# cudf-polars-cu12 25.6.0 requires pylibcudf-cu12==25.6.*, but you have pylibcudf-cu12 25.2.2 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires pylibraft-cu12==25.6.*, but you have pylibraft-cu12 25.2.0 which is incompatible.
# pylibcugraph-cu12 25.6.0 requires rmm-cu12==25.6.*, but you have rmm-cu12 25.2.0 which is incompatible.
# ✅ Successfully logged in to Hugging Face using Kaggle Secret.

# %%
from datasets import load_dataset
import pandas as pd

# Load full dataset
full_dataset = load_dataset('derek-thomas/ScienceQA')

# Analyze dataset structure
print(f"Train samples: {len(full_dataset['train'])}")
print(f"Validation samples: {len(full_dataset['validation'])}")
print(f"Test samples: {len(full_dataset['test'])}")

# Examine sample
sample = full_dataset['train'][0]
print(sample.keys())
# Out:
# 2025-11-24 02:06:44,523 - numexpr.utils - INFO - NumExpr defaulting to 4 threads.
# 2025-11-24 02:06:44,730 - datasets - INFO - TensorFlow version 2.18.0 available.
# 2025-11-24 02:06:44,733 - datasets - INFO - JAX version 0.5.2 available.
# README.md: 0.00B [00:00, ?B/s]
# data/train-00000-of-00001-1028f23e353fbe(…):   0%|          | 0.00/377M [00:00<?, ?B/s]
# data/validation-00000-of-00001-6c7328ff6(…):   0%|          | 0.00/126M [00:00<?, ?B/s]
# data/test-00000-of-00001-f0e719df791966f(…):   0%|          | 0.00/122M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/12726 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/4241 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/4241 [00:00<?, ? examples/s]
# Train samples: 12726
# Validation samples: 4241
# Test samples: 4241
# dict_keys(['image', 'question', 'choices', 'answer', 'hint', 'task', 'grade', 'subject', 'topic', 'category', 'skill', 'lecture', 'solution'])

# %%
# Explore structure
print(full_dataset['train'][1000])

# Create balanced subset across topics
train_subset = full_dataset['train'].shuffle(seed=42).select(range(12000))
val_subset = full_dataset['validation'].shuffle(seed=42).select(range(4000))
test_subset = full_dataset['test'].shuffle(seed=42).select(range(4000))

# Save locally for reuse
train_subset.save_to_disk('data/train_subset')
val_subset.save_to_disk('data/val_subset')
test_subset.save_to_disk('data/test_subset')
# Out:
# {'image': None, 'question': 'Which sentence states a fact?', 'choices': ['Atlanta is the capital of Georgia.', 'Atlanta is too hot in the summer.'], 'answer': 0, 'hint': '', 'task': 'closed choice', 'grade': 'grade5', 'subject': 'social science', 'topic': 'civics', 'category': 'Social studies skills', 'skill': 'Identify facts and opinions', 'lecture': 'A fact is something that can be proved to be true. Facts can be proved by observing, measuring, or studying information.\nThe flag of the United States has 13 stripes.\nThis is a fact. It can be proved by looking at the flag and counting the number of stripes.\nAn opinion is something that a person believes, thinks, or feels. An opinion cannot be proved true.\nThe flag of the United States is easy to draw.\nThis is an opinion. People may have different opinions about what makes a flag "easy" to draw.', 'solution': 'The second sentence states a fact.\nAtlanta is the capital of Georgia.\nIt can be proved by looking at a map of Georgia.\nThe first sentence states an opinion.\nAtlanta is too hot in the summer.\nToo hot shows what a person believes, thinks, or feels. Another person might have a different opinion about how hot is too hot.'}
# Saving the dataset (0/1 shards):   0%|          | 0/12000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
def format_scienceqa_for_chat(example):
    """Convert ScienceQA to conversational format"""

    # Build question with choices
    question = example['question']
    choices = example['choices']
    choices_text = "\n".join([f"{chr(65+i)}. {choice}" for i, choice in enumerate(choices)])

    full_question = f"{question}\n\n{choices_text}"

    # Build answer with explanation
    answer_idx = example['answer']
    correct_answer = choices[answer_idx]

    response = f"The correct answer is {chr(65+answer_idx)}. {correct_answer}"

    # Add explanation if available
    if example.get('solution'):
        response += f"\n\nExplanation: {example['solution']}"

    # Add lecture context if available
    if example.get('lecture'):
        response += f"\n\nBackground: {example['lecture']}"

    # Format as conversational message
    return {
        "messages": [
            {"role": "system", "content": "You are a helpful science tutor for elementary through high school students. Explain concepts clearly with examples."},
            {"role": "user", "content": full_question},
            {"role": "assistant", "content": response}
        ]
    }

# %%
# Apply formatting
train_formatted = train_subset.map(format_scienceqa_for_chat, remove_columns=train_subset.column_names)
val_formatted = val_subset.map(format_scienceqa_for_chat, remove_columns=val_subset.column_names)
test_formatted = test_subset.map(format_scienceqa_for_chat, remove_columns=test_subset.column_names)
# Out:
# Map:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
# persist the formatted splits
train_formatted.save_to_disk("data/train_formatted")
val_formatted.save_to_disk("data/val_formatted")
test_formatted.save_to_disk("data/test_formatted")
# Out:
# Saving the dataset (0/1 shards):   0%|          | 0/12000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]

# %%
from datasets import load_from_disk
from pathlib import Path

# Load PRE-FORMATTED ScienceQA evaluation subset
DATA_DIR = Path("data")

try:
    # Load the data that was already processed in Notebook 1
    test_formatted = load_from_disk(str(DATA_DIR / "test_subset"))
    print(f"Loaded formatted test subset with {len(test_formatted)} examples.")
except FileNotFoundError:
    test_formatted = None
    print("Warning: data/test_formatted not found. Please run Notebook 1 first and save the formatted data.")
# Out:
# Loaded formatted test subset with 4000 examples.

# %%
from datasets import load_from_disk
from pathlib import Path

test_formatted = load_from_disk(str(DATA_DIR / "test_formatted"))
print(f"Loaded formatted test subset with {len(test_formatted)} examples.")

conversations = []
for example in test_formatted:
    messages = example["messages"]  # now present
    conversations.append({
        "id": example.get("id"),
        "conversation": {"messages": messages},
        "expected_response": messages[2]["content"],
    })
print(f"Prepared {len(conversations)} conversations from pre-processed file.")
# Out:
# Loaded formatted test subset with 4000 examples.
# Prepared 4000 conversations from pre-processed file.

# %%
# Prepare conversations from the pre-formatted file
if test_formatted is not None:
    conversations = []
    for example in test_formatted:
        # The assistant's content is the expected response
        conversations.append({
            "id": example.get("id"), # We can still get the ID
            "conversation": {"messages": example["messages"]},
            "expected_response": example["messages"][2]["content"], # 2 is the assistant's message
        })
    print(f"Prepared {len(conversations)} conversations from pre-processed file.")
else:
    conversations = []
# Out:
# Prepared 4000 conversations from pre-processed file.

# %%
# Generate baseline responses (configure sample size as needed)
EVAL_SAMPLE_SIZE = 50  # adjust to cover more/less examples

def evaluate_baseline(sample_size=EVAL_SAMPLE_SIZE, temperature=0.7, top_k=50):
    assert conversations, "No conversations prepared. Ensure Notebook 1 has been run."
    results = []
    for idx, example in enumerate(conversations[:sample_size]):
        convo = example["conversation"]
        generation = generate_response_for_conversation(
            convo,
            max_tokens=256,
            temperature=temperature,
            top_k=top_k,
        )
        results.append({
            "index": idx,
            "example_id": example.get("id"),
            "question": convo["messages"][1]["content"],
            "expected": example["expected_response"],
            "response": generation["response_text"],
            "prompt_tokens": generation["prompt_tokens"],
            "generated_tokens": generation["generated_tokens"],
        })
    return results

# baseline_results = evaluate_baseline()
# len(baseline_results)

# %%
def extract_choice_letter(text):
    for letter in ["A", "B", "C", "D", "E", "F"]:
        if f"{letter}." in text:
            return letter
        if f" {letter} " in text:
            return letter
    return None


def compute_accuracy(results):
    correct = 0
    total = 0
    for entry in results:
        expected_letter = extract_choice_letter(entry["expected"])
        predicted_letter = extract_choice_letter(entry["response"])
        if expected_letter and predicted_letter:
            total += 1
            if expected_letter == predicted_letter:
                correct += 1
    accuracy = correct / total if total else 0.0
    return {
        "evaluated": len(results),
        "scored": total,
        "correct": correct,
        "accuracy": accuracy,
    }

# metrics = compute_accuracy(baseline_results)
# metrics

# %%
def summarize_result(entry, idx=0):
    print(f"Example {idx}")
    print("Question:\n", entry["question"])
    print("\nExpected:\n", entry["expected"])
    print("\nModel Response:\n", entry["response"])

# if baseline_results:
#     summarize_result(baseline_results[0], idx=baseline_results[0]["index"])

# %% [markdown]
# ## Next Steps
#
# 1. Uncomment the evaluation cells to generate baseline responses once the ScienceQA subsets are prepared.
# 2. Review `baseline_responses.json` to confirm output quality before starting fine-tuning.
# 3. Keep an eye on GPU availability; running on CPU will be slow for the full evaluation set.

# %%
# This is the data loader from scripts/chat_sft.py
def sft_data_generator(dataset, batch_size):
    pad_token_id = tokenizer.encode_special("<|assistant_end|>") # use <|assistant_end|> as the pad token is ok, these positions are masked in the loss

    # prepares a list of tokenized conversations into a batch and yields
    def collate_and_yield(batch):
        nrows = len(batch)
        ncols = max(len(ids) for ids, mask in batch) - 1 # seq of n creates inputs/targets of n-1
        inputs = torch.full((nrows, ncols), pad_token_id, dtype=torch.long)
        targets = torch.full((nrows, ncols), -1, dtype=torch.long) # -1 is ignore index
        for i, (ids, mask) in enumerate(batch):
            n = len(ids)
            ids_tensor = torch.tensor(ids, dtype=torch.long)
            inputs[i, :n-1] = ids_tensor[:-1]
            # recall -1 is the ignore index, so mask out targets where mask is 0
            row_targets = ids_tensor[1:]
            # mask[1:] omits the mask for the BOS token, which is never a target atm so it's ok
            mask_tensor = torch.tensor(mask[1:], dtype=torch.long)
            row_targets[mask_tensor == 0] = -1 # mask out targets where mask is 0
            targets[i, :n-1] = row_targets
        inputs = inputs.to(device) # move to device
        targets = targets.to(device)
        return inputs, targets

    # iterates over the dataset in epochs, tokenizes
    batch = []
    while True:
        for i in range(len(dataset)):
            doc = dataset[i]
            ids, mask = tokenizer.render_conversation(doc)
            batch.append((ids, mask))
            if len(batch) == batch_size:
                yield collate_and_yield(batch)
                batch = []

print("Data generator `sft_data_generator` is defined.")
# Out:
# Data generator `sft_data_generator` is defined.

# %%
# Cell: Define project paths
from pathlib import Path

DATA_DIR = Path("data")
DATA_DIR.mkdir(exist_ok=True)

# Define paths for formatted data
train_formatted_path = DATA_DIR / "train_formatted"
val_formatted_path = DATA_DIR / "val_formatted"
test_formatted_path = DATA_DIR / "test_formatted"

# %%
# Cell: Download and subset ScienceQA dataset
from datasets import load_dataset

# Load full dataset
full_dataset = load_dataset('derek-thomas/ScienceQA')

# Create balanced subset for fine-tuning
train_subset = full_dataset['train'].shuffle(seed=42).select(range(12000))
val_subset = full_dataset['validation'].shuffle(seed=42).select(range(4000))
test_subset = full_dataset['test'].shuffle(seed=42).select(range(4000))

print(f"Train subset: {len(train_subset)} | Validation subset: {len(val_subset)} | Test subset: {len(test_subset)}")
# Out:
# Train subset: 12000 | Validation subset: 4000 | Test subset: 4000

# %%
# Cell: Define formatting function
def format_scienceqa_for_chat(example):
    """Convert ScienceQA to conversational format for nanochat."""

    # Build question with choices
    question = example['question']
    choices = example['choices']
    choices_text = "\n".join([f"{chr(65+i)}. {choice}" for i, choice in enumerate(choices)])

    full_question = f"{question}\n\n{choices_text}"

    # Build answer with explanation
    answer_idx = example['answer']
    correct_answer = choices[answer_idx]

    response = f"The correct answer is {chr(65+answer_idx)}. {correct_answer}"

    # Add explanation if available
    if example.get('solution'):
        response += f"\n\nExplanation: {example['solution']}"

    # Add lecture context if available
    if example.get('lecture'):
        response += f"\n\nBackground: {example['lecture']}"

    # Format as conversational message
    return {
        "id": example.get("id"), # Keep id for tracking
        "messages": [
            {"role": "system", "content": "You are a helpful science tutor for elementary through high school students. Explain concepts clearly with examples."},
            {"role": "user", "content": full_question},
            {"role": "assistant", "content": response}
        ]
    }

# %%
# Cell: Apply formatting and save datasets
# Apply formatting
train_formatted = train_subset.map(format_scienceqa_for_chat, remove_columns=train_subset.column_names)
val_formatted = val_subset.map(format_scienceqa_for_chat, remove_columns=val_subset.column_names)
test_formatted = test_subset.map(format_scienceqa_for_chat, remove_columns=test_subset.column_names)

# Save formatted datasets to disk
train_formatted.save_to_disk(str(train_formatted_path))
val_formatted.save_to_disk(str(val_formatted_path))
test_formatted.save_to_disk(str(test_formatted_path))

print(f"Saved formatted datasets to {DATA_DIR}")
print(f"Train: {len(train_formatted)} | Val: {len(val_formatted)} | Test: {len(test_formatted)}")
# Out:
# Map:   0%|          | 0/12000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/12000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]
# Saving the dataset (0/1 shards):   0%|          | 0/4000 [00:00<?, ? examples/s]
# Saved formatted datasets to data
# Train: 12000 | Val: 4000 | Test: 4000

# %%
# Cell: Load formatted datasets for training
from datasets import load_from_disk

# These paths were defined in a previous cell
if not train_formatted_path.exists() or not val_formatted_path.exists():
    raise FileNotFoundError(f"Missing formatted datasets. Please ensure the data preparation cells have been run.")

train_dataset = load_from_disk(str(train_formatted_path))
val_dataset = load_from_disk(str(val_formatted_path))

print(f"Loaded datasets for training. Train samples: {len(train_dataset)} | Validation samples: {len(val_dataset)}")
# Out:
# Loaded datasets for training. Train samples: 12000 | Validation samples: 4000

# %%
# SFT Hyperparameters (adapted from scripts/chat_sft.py)

# Memory-aware batch sizing
if USE_SINGLE_GPU_MODE and ddp_world_size == 1:
    device_batch_size = 1  # Minimum for T4 GPU with ~16GB
    target_examples_per_step = 32  # Keep effective batch size via grad accum
else:
    device_batch_size = 1  # For multi-GPU or larger GPUs
    target_examples_per_step = 8 * ddp_world_size  # Scale with world size

num_epochs = 2
unembedding_lr = 0.004
embedding_lr = 0.2
matrix_lr = 0.02
weight_decay = 0.0
init_lr_frac = 0.02
eval_every = 100  # Steps
eval_steps = 50

# Calculate number of iterations and gradient accumulation
grad_accum_steps = target_examples_per_step // device_batch_size
# Adjust iterations for DDP (each GPU sees a shard)
num_iterations = (len(train_dataset) // (target_examples_per_step * ddp_world_size)) * num_epochs

if ddp_rank == 0:
    print(f"Effective batch size (global): {target_examples_per_step * ddp_world_size}")
    print(f"Device batch size (per GPU): {device_batch_size}")
    print(f"Gradient accumulation steps: {grad_accum_steps}")
    print(f"Total training iterations: {num_iterations}")
    print(f"World size: {ddp_world_size}")

# Create data loaders (generators) - same for both modes
train_loader = sft_data_generator(train_dataset, batch_size=device_batch_size)
val_loader = sft_data_generator(val_dataset, batch_size=device_batch_size)
# Out:
# Effective batch size (global): 32
# Device batch size (per GPU): 1
# Gradient accumulation steps: 32
# Total training iterations: 750
# World size: 1

# %%
optimizers = base_model.setup_optimizers(
    unembedding_lr=unembedding_lr,
    embedding_lr=embedding_lr,
    matrix_lr=matrix_lr,
    weight_decay=weight_decay,
)

ptdtype = torch.bfloat16  # nanochat uses bfloat16

# Set the initial learning rate as a fraction of the base learning rate
for opt in optimizers:
    for group in opt.param_groups:
        group["lr"] = group["lr"] * init_lr_frac
        group["initial_lr"] = group["lr"]  # save the initial learning so we can decay easily later

print("Optimizers initialized.")
# Out:
# Scaling the LR for the AdamW parameters ∝1/√(1280/768) = 0.774597
# Optimizers initialized.

# %%
import time
from contextlib import nullcontext

# Use the device_type from compute_init instead of hardcoding
ptdtype = torch.bfloat16  # nanochat uses bfloat16
autocast_ctx = torch.amp.autocast(device_type=device.type, dtype=ptdtype) if device.type == "cuda" else nullcontext()

# Learning rate scheduler
def get_lr_multiplier(it):
    lrm = 1.0 - it / num_iterations
    return lrm

if ddp_rank == 0:
    print("Starting fine-tuning...")

train_iter = iter(train_loader)
val_iter = iter(val_loader)
val_loss = 0.0
step_time_ema = 0.0

for step in range(num_iterations):
    t0 = time.time()
    last_step = step == num_iterations - 1

    # Validation loop
    if last_step or step % eval_every == 0:
        model.eval()
        if device.type == "cuda":
            torch.cuda.empty_cache()
        losses = []
        for _ in range(eval_steps):
            val_inputs, val_targets = next(val_iter)
            with torch.no_grad(), autocast_ctx:
                loss = model(val_inputs, val_targets)
            losses.append(loss)
        val_loss = torch.stack(losses).mean().item()

        # DDP: synchronize validation loss across ranks
        if ddp:
            val_loss_tensor = torch.tensor(val_loss, device=device)
            torch.distributed.all_reduce(val_loss_tensor, op=torch.distributed.ReduceOp.AVG)
            val_loss = val_loss_tensor.item()

        if ddp_rank == 0:
            print(f"Step {step:05d} | Validation loss: {val_loss:.6f}")
        model.train()

    # Training loop
    num_tokens = 0
    for micro_step in range(grad_accum_steps):
        train_inputs, train_targets = next(train_iter)
        with autocast_ctx:
            loss = model(train_inputs, train_targets)
        train_loss = loss.detach()  # for logging
        loss = loss / grad_accum_steps  # normalize for gradient accumulation
        loss.backward()  # accumulate gradients
        num_tokens += (train_targets >= 0).sum()

    # Update learning rate
    lrm = get_lr_multiplier(step)
    for opt in optimizers:
        for group in opt.param_groups:
            group["lr"] = group["initial_lr"] * lrm

    # Step the optimizers
    for opt in optimizers:
        opt.step()
    model.zero_grad(set_to_none=True)

    # Timing and logging (only rank 0)
    if ddp_rank == 0:
        t1 = time.time()
        dt = t1 - t0
        step_time_ema = dt if step_time_ema == 0 else 0.9 * step_time_ema + 0.1 * dt
        tokens_per_sec = num_tokens.item() / dt
        print(f"Step {step:05d}/{num_iterations:05d} | Train loss: {train_loss.item():.6f} | LR mult: {lrm:.4f} | Tok/s: {tokens_per_sec:,.0f} | Step time: {step_time_ema:.3f}s")

if ddp_rank == 0:
    print("\nTraining complete.")
# Out:
# Starting fine-tuning...
# Step 00000 | Validation loss: 1.884863
# W1124 02:07:27.299000 48 torch/_inductor/utils.py:1137] [0/0] Not enough SMs to use max_autotune_gemm mode
# /usr/local/lib/python3.11/dist-packages/torch/_inductor/compile_fx.py:1948: UserWarning: Tesla P100-PCIE-16GB does not support bfloat16 compilation natively, skipping
#   warnings.warn(
# Step 00000/00750 | Train loss: 3.137879 | LR mult: 1.0000 | Tok/s: 357 | Step time: 16.887s
# Step 00001/00750 | Train loss: 1.594340 | LR mult: 0.9987 | Tok/s: 708 | Step time: 16.090s
# Step 00002/00750 | Train loss: 1.949950 | LR mult: 0.9973 | Tok/s: 634 | Step time: 15.329s
# Step 00003/00750 | Train loss: 1.822210 | LR mult: 0.9960 | Tok/s: 723 | Step time: 14.724s
# Step 00004/00750 | Train loss: 2.193991 | LR mult: 0.9947 | Tok/s: 689 | Step time: 14.119s
# Step 00005/00750 | Train loss: 2.077898 | LR mult: 0.9933 | Tok/s: 669 | Step time: 13.581s
# Step 00006/00750 | Train loss: 1.742413 | LR mult: 0.9920 | Tok/s: 743 | Step time: 13.184s
# Step 00007/00750 | Train loss: 0.816040 | LR mult: 0.9907 | Tok/s: 738 | Step time: 12.796s
# Step 00008/00750 | Train loss: 0.995913 | LR mult: 0.9893 | Tok/s: 817 | Step time: 12.523s
# Step 00009/00750 | Train loss: 1.376194 | LR mult: 0.9880 | Tok/s: 678 | Step time: 12.150s
# Step 00010/00750 | Train loss: 2.318694 | LR mult: 0.9867 | Tok/s: 714 | Step time: 11.838s
# Step 00011/00750 | Train loss: 1.877157 | LR mult: 0.9853 | Tok/s: 753 | Step time: 11.571s
# Step 00012/00750 | Train loss: 2.549303 | LR mult: 0.9840 | Tok/s: 684 | Step time: 11.289s
# Step 00013/00750 | Train loss: 0.635031 | LR mult: 0.9827 | Tok/s: 754 | Step time: 11.113s
# Step 00014/00750 | Train loss: 2.251223 | LR mult: 0.9813 | Tok/s: 730 | Step time: 10.934s
# Step 00015/00750 | Train loss: 1.651722 | LR mult: 0.9800 | Tok/s: 621 | Step time: 10.686s
# Step 00016/00750 | Train loss: 2.065930 | LR mult: 0.9787 | Tok/s: 698 | Step time: 10.507s
# Step 00017/00750 | Train loss: 1.349212 | LR mult: 0.9773 | Tok/s: 592 | Step time: 10.274s
# Step 00018/00750 | Train loss: 1.577714 | LR mult: 0.9760 | Tok/s: 713 | Step time: 10.157s
# Step 00019/00750 | Train loss: 2.704465 | LR mult: 0.9747 | Tok/s: 688 | Step time: 10.014s
# Step 00020/00750 | Train loss: 0.537060 | LR mult: 0.9733 | Tok/s: 605 | Step time: 9.879s
# Step 00021/00750 | Train loss: 1.303279 | LR mult: 0.9720 | Tok/s: 641 | Step time: 9.743s
# Step 00022/00750 | Train loss: 2.790508 | LR mult: 0.9707 | Tok/s: 751 | Step time: 9.695s
# Step 00023/00750 | Train loss: 1.834659 | LR mult: 0.9693 | Tok/s: 572 | Step time: 9.546s
# Step 00024/00750 | Train loss: 1.712973 | LR mult: 0.9680 | Tok/s: 695 | Step time: 9.491s
# Step 00025/00750 | Train loss: 1.748500 | LR mult: 0.9667 | Tok/s: 752 | Step time: 9.490s
# Step 00026/00750 | Train loss: 1.262522 | LR mult: 0.9653 | Tok/s: 783 | Step time: 9.485s
# Step 00027/00750 | Train loss: 1.736030 | LR mult: 0.9640 | Tok/s: 662 | Step time: 9.414s
# Step 00028/00750 | Train loss: 1.827874 | LR mult: 0.9627 | Tok/s: 719 | Step time: 9.350s
# Step 00029/00750 | Train loss: 1.772059 | LR mult: 0.9613 | Tok/s: 585 | Step time: 9.250s
# Step 00030/00750 | Train loss: 1.444231 | LR mult: 0.9600 | Tok/s: 714 | Step time: 9.231s
# Step 00031/00750 | Train loss: 1.754516 | LR mult: 0.9587 | Tok/s: 720 | Step time: 9.216s
# Step 00032/00750 | Train loss: 2.439901 | LR mult: 0.9573 | Tok/s: 712 | Step time: 9.184s
# Step 00033/00750 | Train loss: 1.482039 | LR mult: 0.9560 | Tok/s: 701 | Step time: 9.147s
# Step 00034/00750 | Train loss: 1.897178 | LR mult: 0.9547 | Tok/s: 655 | Step time: 9.080s
# Step 00035/00750 | Train loss: 1.305426 | LR mult: 0.9533 | Tok/s: 696 | Step time: 9.059s
# Step 00036/00750 | Train loss: 1.657692 | LR mult: 0.9520 | Tok/s: 822 | Step time: 9.142s
# Step 00037/00750 | Train loss: 1.100300 | LR mult: 0.9507 | Tok/s: 813 | Step time: 9.230s
# Step 00038/00750 | Train loss: 0.408105 | LR mult: 0.9493 | Tok/s: 616 | Step time: 9.148s
# Step 00039/00750 | Train loss: 1.749746 | LR mult: 0.9480 | Tok/s: 695 | Step time: 9.123s
# Step 00040/00750 | Train loss: 1.770341 | LR mult: 0.9467 | Tok/s: 676 | Step time: 9.105s
# Step 00041/00750 | Train loss: 1.638096 | LR mult: 0.9453 | Tok/s: 672 | Step time: 9.050s
# Step 00042/00750 | Train loss: 1.748339 | LR mult: 0.9440 | Tok/s: 655 | Step time: 9.005s
# Step 00043/00750 | Train loss: 1.270653 | LR mult: 0.9427 | Tok/s: 669 | Step time: 8.987s
# Step 00044/00750 | Train loss: 1.414088 | LR mult: 0.9413 | Tok/s: 725 | Step time: 9.009s
# Step 00045/00750 | Train loss: 0.957843 | LR mult: 0.9400 | Tok/s: 775 | Step time: 9.055s
# Step 00046/00750 | Train loss: 1.869329 | LR mult: 0.9387 | Tok/s: 687 | Step time: 9.024s
# Step 00047/00750 | Train loss: 1.603225 | LR mult: 0.9373 | Tok/s: 685 | Step time: 9.004s
# Step 00048/00750 | Train loss: 1.615735 | LR mult: 0.9360 | Tok/s: 702 | Step time: 9.017s
# Step 00049/00750 | Train loss: 1.326826 | LR mult: 0.9347 | Tok/s: 688 | Step time: 9.001s
# Step 00050/00750 | Train loss: 1.701978 | LR mult: 0.9333 | Tok/s: 737 | Step time: 9.017s
# Step 00051/00750 | Train loss: 1.580095 | LR mult: 0.9320 | Tok/s: 693 | Step time: 8.999s
# Step 00052/00750 | Train loss: 1.526932 | LR mult: 0.9307 | Tok/s: 597 | Step time: 8.939s
# Step 00053/00750 | Train loss: 1.818941 | LR mult: 0.9293 | Tok/s: 635 | Step time: 8.890s
# Step 00054/00750 | Train loss: 1.300856 | LR mult: 0.9280 | Tok/s: 677 | Step time: 8.874s
# Step 00055/00750 | Train loss: 1.111369 | LR mult: 0.9267 | Tok/s: 802 | Step time: 8.978s
# Step 00056/00750 | Train loss: 1.271400 | LR mult: 0.9253 | Tok/s: 716 | Step time: 8.987s
# Step 00057/00750 | Train loss: 0.350881 | LR mult: 0.9240 | Tok/s: 681 | Step time: 8.966s
# Step 00058/00750 | Train loss: 1.898783 | LR mult: 0.9227 | Tok/s: 768 | Step time: 9.027s
# Step 00059/00750 | Train loss: 1.224188 | LR mult: 0.9213 | Tok/s: 798 | Step time: 9.085s
# Step 00060/00750 | Train loss: 0.315512 | LR mult: 0.9200 | Tok/s: 613 | Step time: 9.032s
# Step 00061/00750 | Train loss: 1.650398 | LR mult: 0.9187 | Tok/s: 712 | Step time: 9.056s
# Step 00062/00750 | Train loss: 0.280554 | LR mult: 0.9173 | Tok/s: 691 | Step time: 9.043s
# Step 00063/00750 | Train loss: 1.416214 | LR mult: 0.9160 | Tok/s: 677 | Step time: 9.023s
# Step 00064/00750 | Train loss: 0.382668 | LR mult: 0.9147 | Tok/s: 710 | Step time: 9.028s
# Step 00065/00750 | Train loss: 1.412803 | LR mult: 0.9133 | Tok/s: 632 | Step time: 8.971s
# Step 00066/00750 | Train loss: 1.059064 | LR mult: 0.9120 | Tok/s: 596 | Step time: 8.890s
# Step 00067/00750 | Train loss: 1.623339 | LR mult: 0.9107 | Tok/s: 701 | Step time: 8.901s
# Step 00068/00750 | Train loss: 0.461242 | LR mult: 0.9093 | Tok/s: 560 | Step time: 8.830s
# Step 00069/00750 | Train loss: 2.322246 | LR mult: 0.9080 | Tok/s: 815 | Step time: 8.945s
# Step 00070/00750 | Train loss: 1.823836 | LR mult: 0.9067 | Tok/s: 664 | Step time: 8.909s
# Step 00071/00750 | Train loss: 1.381437 | LR mult: 0.9053 | Tok/s: 661 | Step time: 8.894s
# Step 00072/00750 | Train loss: 0.422745 | LR mult: 0.9040 | Tok/s: 738 | Step time: 8.966s
# Step 00073/00750 | Train loss: 1.366010 | LR mult: 0.9027 | Tok/s: 688 | Step time: 8.955s
# Step 00074/00750 | Train loss: 1.529794 | LR mult: 0.9013 | Tok/s: 698 | Step time: 8.933s
# Step 00075/00750 | Train loss: 1.316959 | LR mult: 0.9000 | Tok/s: 595 | Step time: 8.866s
# Step 00076/00750 | Train loss: 1.599809 | LR mult: 0.8987 | Tok/s: 708 | Step time: 8.875s
# Step 00077/00750 | Train loss: 1.182942 | LR mult: 0.8973 | Tok/s: 681 | Step time: 8.856s
# Step 00078/00750 | Train loss: 1.267769 | LR mult: 0.8960 | Tok/s: 741 | Step time: 8.903s
# Step 00079/00750 | Train loss: 1.675145 | LR mult: 0.8947 | Tok/s: 715 | Step time: 8.915s
# Step 00080/00750 | Train loss: 1.304548 | LR mult: 0.8933 | Tok/s: 660 | Step time: 8.908s
# Step 00081/00750 | Train loss: 1.472489 | LR mult: 0.8920 | Tok/s: 707 | Step time: 8.907s
# Step 00082/00750 | Train loss: 1.145597 | LR mult: 0.8907 | Tok/s: 611 | Step time: 8.847s
# Step 00083/00750 | Train loss: 1.590330 | LR mult: 0.8893 | Tok/s: 684 | Step time: 8.823s
# Step 00084/00750 | Train loss: 1.081403 | LR mult: 0.8880 | Tok/s: 657 | Step time: 8.814s
# Step 00085/00750 | Train loss: 0.161097 | LR mult: 0.8867 | Tok/s: 606 | Step time: 8.764s
# Step 00086/00750 | Train loss: 1.302940 | LR mult: 0.8853 | Tok/s: 679 | Step time: 8.778s
# Step 00087/00750 | Train loss: 1.134415 | LR mult: 0.8840 | Tok/s: 702 | Step time: 8.809s
# Step 00088/00750 | Train loss: 0.910028 | LR mult: 0.8827 | Tok/s: 706 | Step time: 8.824s
# Step 00089/00750 | Train loss: 0.304559 | LR mult: 0.8813 | Tok/s: 622 | Step time: 8.793s
# Step 00090/00750 | Train loss: 0.183786 | LR mult: 0.8800 | Tok/s: 683 | Step time: 8.808s
# Step 00091/00750 | Train loss: 1.618708 | LR mult: 0.8787 | Tok/s: 720 | Step time: 8.829s
# Step 00092/00750 | Train loss: 1.526078 | LR mult: 0.8773 | Tok/s: 748 | Step time: 8.891s
# Step 00093/00750 | Train loss: 0.963403 | LR mult: 0.8760 | Tok/s: 669 | Step time: 8.886s
# Step 00094/00750 | Train loss: 0.289864 | LR mult: 0.8747 | Tok/s: 809 | Step time: 8.982s
# Step 00095/00750 | Train loss: 1.964545 | LR mult: 0.8733 | Tok/s: 659 | Step time: 8.960s
# Step 00096/00750 | Train loss: 1.025809 | LR mult: 0.8720 | Tok/s: 627 | Step time: 8.907s
# Step 00097/00750 | Train loss: 0.177289 | LR mult: 0.8707 | Tok/s: 681 | Step time: 8.916s
# Step 00098/00750 | Train loss: 1.916095 | LR mult: 0.8693 | Tok/s: 679 | Step time: 8.918s
# Step 00099/00750 | Train loss: 1.069523 | LR mult: 0.8680 | Tok/s: 750 | Step time: 8.962s
# Step 00100 | Validation loss: 1.022231
# Step 00100/00750 | Train loss: 1.276068 | LR mult: 0.8667 | Tok/s: 484 | Step time: 9.395s
# Step 00101/00750 | Train loss: 1.473293 | LR mult: 0.8653 | Tok/s: 729 | Step time: 9.367s
# Step 00102/00750 | Train loss: 0.233229 | LR mult: 0.8640 | Tok/s: 700 | Step time: 9.331s
# Step 00103/00750 | Train loss: 0.171216 | LR mult: 0.8627 | Tok/s: 629 | Step time: 9.256s
# Step 00104/00750 | Train loss: 1.253618 | LR mult: 0.8613 | Tok/s: 690 | Step time: 9.242s
# Step 00105/00750 | Train loss: 1.363904 | LR mult: 0.8600 | Tok/s: 742 | Step time: 9.233s
# Step 00106/00750 | Train loss: 1.136339 | LR mult: 0.8587 | Tok/s: 731 | Step time: 9.226s
# Step 00107/00750 | Train loss: 0.209340 | LR mult: 0.8573 | Tok/s: 716 | Step time: 9.201s
# Step 00108/00750 | Train loss: 1.441287 | LR mult: 0.8560 | Tok/s: 671 | Step time: 9.160s
# Step 00109/00750 | Train loss: 1.334261 | LR mult: 0.8547 | Tok/s: 656 | Step time: 9.114s
# Step 00110/00750 | Train loss: 1.377890 | LR mult: 0.8533 | Tok/s: 687 | Step time: 9.094s
# Step 00111/00750 | Train loss: 1.536679 | LR mult: 0.8520 | Tok/s: 665 | Step time: 9.059s
# Step 00112/00750 | Train loss: 1.009865 | LR mult: 0.8507 | Tok/s: 736 | Step time: 9.073s
# Step 00113/00750 | Train loss: 0.993423 | LR mult: 0.8493 | Tok/s: 680 | Step time: 9.048s
# Step 00114/00750 | Train loss: 1.077213 | LR mult: 0.8480 | Tok/s: 614 | Step time: 8.980s
# Step 00115/00750 | Train loss: 1.045292 | LR mult: 0.8467 | Tok/s: 665 | Step time: 8.941s
# Step 00116/00750 | Train loss: 0.808154 | LR mult: 0.8453 | Tok/s: 672 | Step time: 8.916s
# Step 00117/00750 | Train loss: 1.382966 | LR mult: 0.8440 | Tok/s: 713 | Step time: 8.916s
# Step 00118/00750 | Train loss: 0.790771 | LR mult: 0.8427 | Tok/s: 719 | Step time: 8.946s
# Step 00119/00750 | Train loss: 1.123098 | LR mult: 0.8413 | Tok/s: 754 | Step time: 8.966s
# Step 00120/00750 | Train loss: 0.713572 | LR mult: 0.8400 | Tok/s: 684 | Step time: 8.958s
# Step 00121/00750 | Train loss: 0.572812 | LR mult: 0.8387 | Tok/s: 729 | Step time: 8.972s
# Step 00122/00750 | Train loss: 1.011892 | LR mult: 0.8373 | Tok/s: 668 | Step time: 8.943s
# Step 00123/00750 | Train loss: 0.242082 | LR mult: 0.8360 | Tok/s: 656 | Step time: 8.921s
# Step 00124/00750 | Train loss: 1.319334 | LR mult: 0.8347 | Tok/s: 754 | Step time: 8.974s
# Step 00125/00750 | Train loss: 0.967418 | LR mult: 0.8333 | Tok/s: 672 | Step time: 8.947s
# Step 00126/00750 | Train loss: 1.401110 | LR mult: 0.8320 | Tok/s: 654 | Step time: 8.906s
# Step 00127/00750 | Train loss: 1.499623 | LR mult: 0.8307 | Tok/s: 721 | Step time: 8.917s
# Step 00128/00750 | Train loss: 1.114914 | LR mult: 0.8293 | Tok/s: 710 | Step time: 8.910s
# Step 00129/00750 | Train loss: 1.813539 | LR mult: 0.8280 | Tok/s: 719 | Step time: 8.939s
# Step 00130/00750 | Train loss: 0.069766 | LR mult: 0.8267 | Tok/s: 772 | Step time: 8.991s
# Step 00131/00750 | Train loss: 1.092812 | LR mult: 0.8253 | Tok/s: 740 | Step time: 9.028s
# Step 00132/00750 | Train loss: 1.072674 | LR mult: 0.8240 | Tok/s: 807 | Step time: 9.099s
# Step 00133/00750 | Train loss: 0.081917 | LR mult: 0.8227 | Tok/s: 681 | Step time: 9.094s
# Step 00134/00750 | Train loss: 2.019712 | LR mult: 0.8213 | Tok/s: 759 | Step time: 9.118s
# Step 00135/00750 | Train loss: 1.211491 | LR mult: 0.8200 | Tok/s: 763 | Step time: 9.166s
# Step 00136/00750 | Train loss: 0.595858 | LR mult: 0.8187 | Tok/s: 731 | Step time: 9.163s
# Step 00137/00750 | Train loss: 0.575587 | LR mult: 0.8173 | Tok/s: 687 | Step time: 9.125s
# Step 00138/00750 | Train loss: 0.675740 | LR mult: 0.8160 | Tok/s: 686 | Step time: 9.102s
# Step 00139/00750 | Train loss: 1.315810 | LR mult: 0.8147 | Tok/s: 721 | Step time: 9.101s
# Step 00140/00750 | Train loss: 0.098692 | LR mult: 0.8133 | Tok/s: 703 | Step time: 9.100s
# Step 00141/00750 | Train loss: 0.993527 | LR mult: 0.8120 | Tok/s: 628 | Step time: 9.050s
# Step 00142/00750 | Train loss: 1.183362 | LR mult: 0.8107 | Tok/s: 682 | Step time: 9.021s
# Step 00143/00750 | Train loss: 0.759143 | LR mult: 0.8093 | Tok/s: 717 | Step time: 9.026s
# Step 00144/00750 | Train loss: 0.558068 | LR mult: 0.8080 | Tok/s: 682 | Step time: 9.005s
# Step 00145/00750 | Train loss: 0.168731 | LR mult: 0.8067 | Tok/s: 628 | Step time: 8.949s
# Step 00146/00750 | Train loss: 0.740561 | LR mult: 0.8053 | Tok/s: 667 | Step time: 8.944s
# Step 00147/00750 | Train loss: 0.966062 | LR mult: 0.8040 | Tok/s: 756 | Step time: 8.976s
# Step 00148/00750 | Train loss: 1.128988 | LR mult: 0.8027 | Tok/s: 715 | Step time: 8.992s
# Step 00149/00750 | Train loss: 2.491727 | LR mult: 0.8013 | Tok/s: 607 | Step time: 8.939s
# Step 00150/00750 | Train loss: 1.916400 | LR mult: 0.8000 | Tok/s: 767 | Step time: 9.016s
# Step 00151/00750 | Train loss: 1.202831 | LR mult: 0.7987 | Tok/s: 693 | Step time: 8.995s
# Step 00152/00750 | Train loss: 2.161203 | LR mult: 0.7973 | Tok/s: 737 | Step time: 9.026s
# Step 00153/00750 | Train loss: 1.088438 | LR mult: 0.7960 | Tok/s: 705 | Step time: 9.015s
# Step 00154/00750 | Train loss: 1.075931 | LR mult: 0.7947 | Tok/s: 733 | Step time: 9.047s
# Step 00155/00750 | Train loss: 0.213973 | LR mult: 0.7933 | Tok/s: 853 | Step time: 9.187s
# Step 00156/00750 | Train loss: 0.153822 | LR mult: 0.7920 | Tok/s: 726 | Step time: 9.181s
# Step 00157/00750 | Train loss: 0.455550 | LR mult: 0.7907 | Tok/s: 680 | Step time: 9.139s
# Step 00158/00750 | Train loss: 1.071471 | LR mult: 0.7893 | Tok/s: 697 | Step time: 9.131s
# Step 00159/00750 | Train loss: 0.588955 | LR mult: 0.7880 | Tok/s: 846 | Step time: 9.229s
# Step 00160/00750 | Train loss: 1.206754 | LR mult: 0.7867 | Tok/s: 709 | Step time: 9.191s
# Step 00161/00750 | Train loss: 1.194203 | LR mult: 0.7853 | Tok/s: 681 | Step time: 9.147s
# Step 00162/00750 | Train loss: 0.991107 | LR mult: 0.7840 | Tok/s: 700 | Step time: 9.112s
# Step 00163/00750 | Train loss: 0.653383 | LR mult: 0.7827 | Tok/s: 719 | Step time: 9.101s
# Step 00164/00750 | Train loss: 1.259114 | LR mult: 0.7813 | Tok/s: 737 | Step time: 9.106s
# Step 00165/00750 | Train loss: 0.418688 | LR mult: 0.7800 | Tok/s: 663 | Step time: 9.040s
# Step 00166/00750 | Train loss: 1.402214 | LR mult: 0.7787 | Tok/s: 666 | Step time: 9.019s
# Step 00167/00750 | Train loss: 1.099509 | LR mult: 0.7773 | Tok/s: 720 | Step time: 9.035s
# Step 00168/00750 | Train loss: 1.162214 | LR mult: 0.7760 | Tok/s: 719 | Step time: 9.024s
# Step 00169/00750 | Train loss: 0.611601 | LR mult: 0.7747 | Tok/s: 676 | Step time: 8.996s
# Step 00170/00750 | Train loss: 0.124532 | LR mult: 0.7733 | Tok/s: 684 | Step time: 8.983s
# Step 00171/00750 | Train loss: 0.998253 | LR mult: 0.7720 | Tok/s: 708 | Step time: 8.984s
# Step 00172/00750 | Train loss: 1.759029 | LR mult: 0.7707 | Tok/s: 662 | Step time: 8.935s
# Step 00173/00750 | Train loss: 0.726053 | LR mult: 0.7693 | Tok/s: 696 | Step time: 8.958s
# Step 00174/00750 | Train loss: 1.226579 | LR mult: 0.7680 | Tok/s: 687 | Step time: 8.940s
# Step 00175/00750 | Train loss: 1.227891 | LR mult: 0.7667 | Tok/s: 727 | Step time: 8.971s
# Step 00176/00750 | Train loss: 0.328313 | LR mult: 0.7653 | Tok/s: 722 | Step time: 8.983s
# Step 00177/00750 | Train loss: 1.052985 | LR mult: 0.7640 | Tok/s: 727 | Step time: 9.002s
# Step 00178/00750 | Train loss: 0.647644 | LR mult: 0.7627 | Tok/s: 594 | Step time: 8.923s
# Step 00179/00750 | Train loss: 1.064542 | LR mult: 0.7613 | Tok/s: 707 | Step time: 8.966s
# Step 00180/00750 | Train loss: 0.309017 | LR mult: 0.7600 | Tok/s: 664 | Step time: 8.948s
# Step 00181/00750 | Train loss: 0.516674 | LR mult: 0.7587 | Tok/s: 711 | Step time: 8.961s
# Step 00182/00750 | Train loss: 1.717320 | LR mult: 0.7573 | Tok/s: 639 | Step time: 8.926s
# Step 00183/00750 | Train loss: 0.364228 | LR mult: 0.7560 | Tok/s: 615 | Step time: 8.871s
# Step 00184/00750 | Train loss: 1.019653 | LR mult: 0.7547 | Tok/s: 676 | Step time: 8.859s
# Step 00185/00750 | Train loss: 1.012593 | LR mult: 0.7533 | Tok/s: 633 | Step time: 8.838s
# Step 00186/00750 | Train loss: 1.561256 | LR mult: 0.7520 | Tok/s: 692 | Step time: 8.854s
# Step 00187/00750 | Train loss: 1.415226 | LR mult: 0.7507 | Tok/s: 710 | Step time: 8.872s
# Step 00188/00750 | Train loss: 0.821808 | LR mult: 0.7493 | Tok/s: 631 | Step time: 8.854s
# Step 00189/00750 | Train loss: 1.143961 | LR mult: 0.7480 | Tok/s: 701 | Step time: 8.888s
# Step 00190/00750 | Train loss: 0.969465 | LR mult: 0.7467 | Tok/s: 633 | Step time: 8.848s
# Step 00191/00750 | Train loss: 0.302649 | LR mult: 0.7453 | Tok/s: 671 | Step time: 8.839s
# Step 00192/00750 | Train loss: 0.735982 | LR mult: 0.7440 | Tok/s: 673 | Step time: 8.818s
# Step 00193/00750 | Train loss: 1.005409 | LR mult: 0.7427 | Tok/s: 753 | Step time: 8.867s
# Step 00194/00750 | Train loss: 0.333532 | LR mult: 0.7413 | Tok/s: 626 | Step time: 8.824s
# Step 00195/00750 | Train loss: 1.672297 | LR mult: 0.7400 | Tok/s: 596 | Step time: 8.777s
# Step 00196/00750 | Train loss: 0.495845 | LR mult: 0.7387 | Tok/s: 684 | Step time: 8.775s
# Step 00197/00750 | Train loss: 0.043676 | LR mult: 0.7373 | Tok/s: 738 | Step time: 8.812s
# Step 00198/00750 | Train loss: 1.174563 | LR mult: 0.7360 | Tok/s: 712 | Step time: 8.848s
# Step 00199/00750 | Train loss: 1.053846 | LR mult: 0.7347 | Tok/s: 715 | Step time: 8.891s
# Step 00200 | Validation loss: 0.840130
# Step 00200/00750 | Train loss: 0.947236 | LR mult: 0.7333 | Tok/s: 488 | Step time: 9.362s
# Step 00201/00750 | Train loss: 0.117122 | LR mult: 0.7320 | Tok/s: 688 | Step time: 9.341s
# Step 00202/00750 | Train loss: 0.755865 | LR mult: 0.7307 | Tok/s: 653 | Step time: 9.268s
# Step 00203/00750 | Train loss: 0.735507 | LR mult: 0.7293 | Tok/s: 739 | Step time: 9.248s
# Step 00204/00750 | Train loss: 0.617669 | LR mult: 0.7280 | Tok/s: 604 | Step time: 9.151s
# Step 00205/00750 | Train loss: 0.991222 | LR mult: 0.7267 | Tok/s: 656 | Step time: 9.088s
# Step 00206/00750 | Train loss: 0.192511 | LR mult: 0.7253 | Tok/s: 731 | Step time: 9.101s
# Step 00207/00750 | Train loss: 0.863517 | LR mult: 0.7240 | Tok/s: 676 | Step time: 9.070s
# Step 00208/00750 | Train loss: 1.506883 | LR mult: 0.7227 | Tok/s: 718 | Step time: 9.061s
# Step 00209/00750 | Train loss: 0.706699 | LR mult: 0.7213 | Tok/s: 668 | Step time: 9.026s
# Step 00210/00750 | Train loss: 0.220336 | LR mult: 0.7200 | Tok/s: 684 | Step time: 9.001s
# Step 00211/00750 | Train loss: 0.084129 | LR mult: 0.7187 | Tok/s: 672 | Step time: 8.971s
# Step 00212/00750 | Train loss: 0.671539 | LR mult: 0.7173 | Tok/s: 731 | Step time: 8.982s
# Step 00213/00750 | Train loss: 0.115907 | LR mult: 0.7160 | Tok/s: 699 | Step time: 8.968s
# Step 00214/00750 | Train loss: 0.635842 | LR mult: 0.7147 | Tok/s: 654 | Step time: 8.930s
# Step 00215/00750 | Train loss: 0.360223 | LR mult: 0.7133 | Tok/s: 693 | Step time: 8.944s
# Step 00216/00750 | Train loss: 0.884717 | LR mult: 0.7120 | Tok/s: 670 | Step time: 8.947s
# Step 00217/00750 | Train loss: 1.037103 | LR mult: 0.7107 | Tok/s: 708 | Step time: 8.972s
# Step 00218/00750 | Train loss: 0.572719 | LR mult: 0.7093 | Tok/s: 649 | Step time: 8.931s
# Step 00219/00750 | Train loss: 0.820748 | LR mult: 0.7080 | Tok/s: 582 | Step time: 8.863s
# Step 00220/00750 | Train loss: 0.103339 | LR mult: 0.7067 | Tok/s: 636 | Step time: 8.828s
# Step 00221/00750 | Train loss: 1.285722 | LR mult: 0.7053 | Tok/s: 738 | Step time: 8.872s
# Step 00222/00750 | Train loss: 1.186949 | LR mult: 0.7040 | Tok/s: 696 | Step time: 8.863s
# Step 00223/00750 | Train loss: 0.546861 | LR mult: 0.7027 | Tok/s: 671 | Step time: 8.849s
# Step 00224/00750 | Train loss: 0.941256 | LR mult: 0.7013 | Tok/s: 682 | Step time: 8.833s
# Step 00225/00750 | Train loss: 1.183992 | LR mult: 0.7000 | Tok/s: 699 | Step time: 8.830s
# Step 00226/00750 | Train loss: 1.040207 | LR mult: 0.6987 | Tok/s: 598 | Step time: 8.774s
# Step 00227/00750 | Train loss: 1.142578 | LR mult: 0.6973 | Tok/s: 685 | Step time: 8.776s
# Step 00228/00750 | Train loss: 0.814783 | LR mult: 0.6960 | Tok/s: 707 | Step time: 8.815s
# Step 00229/00750 | Train loss: 1.089604 | LR mult: 0.6947 | Tok/s: 716 | Step time: 8.817s
# Step 00230/00750 | Train loss: 0.422771 | LR mult: 0.6933 | Tok/s: 744 | Step time: 8.849s
# Step 00231/00750 | Train loss: 1.387242 | LR mult: 0.6920 | Tok/s: 639 | Step time: 8.811s
# Step 00232/00750 | Train loss: 0.127402 | LR mult: 0.6907 | Tok/s: 726 | Step time: 8.829s
# Step 00233/00750 | Train loss: 0.749700 | LR mult: 0.6893 | Tok/s: 811 | Step time: 8.944s
# Step 00234/00750 | Train loss: 1.017971 | LR mult: 0.6880 | Tok/s: 691 | Step time: 8.933s
# Step 00235/00750 | Train loss: 2.146645 | LR mult: 0.6867 | Tok/s: 718 | Step time: 8.951s
# Step 00236/00750 | Train loss: 1.343665 | LR mult: 0.6853 | Tok/s: 679 | Step time: 8.920s
# Step 00237/00750 | Train loss: 0.591279 | LR mult: 0.6840 | Tok/s: 716 | Step time: 8.958s
# Step 00238/00750 | Train loss: 0.400295 | LR mult: 0.6827 | Tok/s: 792 | Step time: 9.050s
# Step 00239/00750 | Train loss: 0.732528 | LR mult: 0.6813 | Tok/s: 631 | Step time: 8.994s
# Step 00240/00750 | Train loss: 0.111381 | LR mult: 0.6800 | Tok/s: 689 | Step time: 8.967s
# Step 00241/00750 | Train loss: 0.543525 | LR mult: 0.6787 | Tok/s: 745 | Step time: 8.993s
# Step 00242/00750 | Train loss: 0.629560 | LR mult: 0.6773 | Tok/s: 785 | Step time: 9.063s
# Step 00243/00750 | Train loss: 0.067521 | LR mult: 0.6760 | Tok/s: 739 | Step time: 9.076s
# Step 00244/00750 | Train loss: 0.963494 | LR mult: 0.6747 | Tok/s: 657 | Step time: 9.041s
# Step 00245/00750 | Train loss: 0.165354 | LR mult: 0.6733 | Tok/s: 699 | Step time: 9.019s
# Step 00246/00750 | Train loss: 0.122845 | LR mult: 0.6720 | Tok/s: 738 | Step time: 9.058s
# Step 00247/00750 | Train loss: 1.258950 | LR mult: 0.6707 | Tok/s: 660 | Step time: 9.044s
# Step 00248/00750 | Train loss: 0.107832 | LR mult: 0.6693 | Tok/s: 651 | Step time: 9.007s
# Step 00249/00750 | Train loss: 0.960562 | LR mult: 0.6680 | Tok/s: 652 | Step time: 8.979s
# Step 00250/00750 | Train loss: 0.666504 | LR mult: 0.6667 | Tok/s: 762 | Step time: 9.039s
# Step 00251/00750 | Train loss: 0.101791 | LR mult: 0.6653 | Tok/s: 687 | Step time: 9.044s
# Step 00252/00750 | Train loss: 0.728955 | LR mult: 0.6640 | Tok/s: 640 | Step time: 8.992s
# Step 00253/00750 | Train loss: 0.041097 | LR mult: 0.6627 | Tok/s: 733 | Step time: 9.024s
# Step 00254/00750 | Train loss: 0.970559 | LR mult: 0.6613 | Tok/s: 660 | Step time: 8.986s
# Step 00255/00750 | Train loss: 1.093385 | LR mult: 0.6600 | Tok/s: 733 | Step time: 9.002s
# Step 00256/00750 | Train loss: 0.953056 | LR mult: 0.6587 | Tok/s: 616 | Step time: 8.938s
# Step 00257/00750 | Train loss: 0.040626 | LR mult: 0.6573 | Tok/s: 705 | Step time: 8.931s
# Step 00258/00750 | Train loss: 0.209052 | LR mult: 0.6560 | Tok/s: 735 | Step time: 8.954s
# Step 00259/00750 | Train loss: 0.096265 | LR mult: 0.6547 | Tok/s: 652 | Step time: 8.916s
# Step 00260/00750 | Train loss: 0.084413 | LR mult: 0.6533 | Tok/s: 661 | Step time: 8.896s
# Step 00261/00750 | Train loss: 0.079075 | LR mult: 0.6520 | Tok/s: 692 | Step time: 8.889s
# Step 00262/00750 | Train loss: 1.321903 | LR mult: 0.6507 | Tok/s: 726 | Step time: 8.926s
# Step 00263/00750 | Train loss: 0.497256 | LR mult: 0.6493 | Tok/s: 657 | Step time: 8.888s
# Step 00264/00750 | Train loss: 1.501812 | LR mult: 0.6480 | Tok/s: 737 | Step time: 8.938s
# Step 00265/00750 | Train loss: 0.472772 | LR mult: 0.6467 | Tok/s: 686 | Step time: 8.929s
# Step 00266/00750 | Train loss: 0.977801 | LR mult: 0.6453 | Tok/s: 681 | Step time: 8.939s
# Step 00267/00750 | Train loss: 0.342560 | LR mult: 0.6440 | Tok/s: 732 | Step time: 8.944s
# Step 00268/00750 | Train loss: 0.282919 | LR mult: 0.6427 | Tok/s: 669 | Step time: 8.912s
# Step 00269/00750 | Train loss: 0.375028 | LR mult: 0.6413 | Tok/s: 761 | Step time: 8.946s
# Step 00270/00750 | Train loss: 0.282909 | LR mult: 0.6400 | Tok/s: 673 | Step time: 8.952s
# Step 00271/00750 | Train loss: 0.353305 | LR mult: 0.6387 | Tok/s: 687 | Step time: 8.945s
# Step 00272/00750 | Train loss: 0.746952 | LR mult: 0.6373 | Tok/s: 736 | Step time: 8.986s
# Step 00273/00750 | Train loss: 0.451152 | LR mult: 0.6360 | Tok/s: 778 | Step time: 9.030s
# Step 00274/00750 | Train loss: 2.669694 | LR mult: 0.6347 | Tok/s: 676 | Step time: 9.022s
# Step 00275/00750 | Train loss: 0.870322 | LR mult: 0.6333 | Tok/s: 720 | Step time: 9.044s
# Step 00276/00750 | Train loss: 0.643097 | LR mult: 0.6320 | Tok/s: 638 | Step time: 9.006s
# Step 00277/00750 | Train loss: 0.112362 | LR mult: 0.6307 | Tok/s: 647 | Step time: 8.945s
# Step 00278/00750 | Train loss: 1.117431 | LR mult: 0.6293 | Tok/s: 613 | Step time: 8.892s
# Step 00279/00750 | Train loss: 0.477216 | LR mult: 0.6280 | Tok/s: 717 | Step time: 8.913s
# Step 00280/00750 | Train loss: 0.863378 | LR mult: 0.6267 | Tok/s: 739 | Step time: 8.938s
# Step 00281/00750 | Train loss: 0.080186 | LR mult: 0.6253 | Tok/s: 611 | Step time: 8.892s
# Step 00282/00750 | Train loss: 0.853577 | LR mult: 0.6240 | Tok/s: 657 | Step time: 8.859s
# Step 00283/00750 | Train loss: 0.407865 | LR mult: 0.6227 | Tok/s: 619 | Step time: 8.823s
# Step 00284/00750 | Train loss: 0.685792 | LR mult: 0.6213 | Tok/s: 740 | Step time: 8.877s
# Step 00285/00750 | Train loss: 0.109934 | LR mult: 0.6200 | Tok/s: 672 | Step time: 8.863s
# Step 00286/00750 | Train loss: 0.932746 | LR mult: 0.6187 | Tok/s: 687 | Step time: 8.870s
# Step 00287/00750 | Train loss: 0.320554 | LR mult: 0.6173 | Tok/s: 662 | Step time: 8.862s
# Step 00288/00750 | Train loss: 0.079216 | LR mult: 0.6160 | Tok/s: 713 | Step time: 8.885s
# Step 00289/00750 | Train loss: 0.904742 | LR mult: 0.6147 | Tok/s: 737 | Step time: 8.932s
# Step 00290/00750 | Train loss: 1.030601 | LR mult: 0.6133 | Tok/s: 806 | Step time: 9.037s
# Step 00291/00750 | Train loss: 1.360839 | LR mult: 0.6120 | Tok/s: 698 | Step time: 9.021s
# Step 00292/00750 | Train loss: 0.084590 | LR mult: 0.6107 | Tok/s: 718 | Step time: 9.046s
# Step 00293/00750 | Train loss: 0.177681 | LR mult: 0.6093 | Tok/s: 629 | Step time: 9.002s
# Step 00294/00750 | Train loss: 0.078594 | LR mult: 0.6080 | Tok/s: 636 | Step time: 8.956s
# Step 00295/00750 | Train loss: 0.319804 | LR mult: 0.6067 | Tok/s: 683 | Step time: 8.945s
# Step 00296/00750 | Train loss: 1.262378 | LR mult: 0.6053 | Tok/s: 716 | Step time: 8.943s
# Step 00297/00750 | Train loss: 0.830352 | LR mult: 0.6040 | Tok/s: 755 | Step time: 8.996s
# Step 00298/00750 | Train loss: 1.172836 | LR mult: 0.6027 | Tok/s: 678 | Step time: 8.967s
# Step 00299/00750 | Train loss: 0.069005 | LR mult: 0.6013 | Tok/s: 639 | Step time: 8.916s
# Step 00300 | Validation loss: 0.536662
# Step 00300/00750 | Train loss: 1.698324 | LR mult: 0.6000 | Tok/s: 380 | Step time: 9.272s
# Step 00301/00750 | Train loss: 0.023853 | LR mult: 0.5987 | Tok/s: 699 | Step time: 9.230s
# Step 00302/00750 | Train loss: 0.247628 | LR mult: 0.5973 | Tok/s: 682 | Step time: 9.200s
# Step 00303/00750 | Train loss: 0.974916 | LR mult: 0.5960 | Tok/s: 690 | Step time: 9.153s
# Step 00304/00750 | Train loss: 1.381481 | LR mult: 0.5947 | Tok/s: 653 | Step time: 9.099s
# Step 00305/00750 | Train loss: 0.049061 | LR mult: 0.5933 | Tok/s: 728 | Step time: 9.096s
# Step 00306/00750 | Train loss: 0.632923 | LR mult: 0.5920 | Tok/s: 692 | Step time: 9.065s
# Step 00307/00750 | Train loss: 0.547248 | LR mult: 0.5907 | Tok/s: 670 | Step time: 9.024s
# Step 00308/00750 | Train loss: 0.063686 | LR mult: 0.5893 | Tok/s: 619 | Step time: 8.963s
# Step 00309/00750 | Train loss: 0.340719 | LR mult: 0.5880 | Tok/s: 736 | Step time: 8.986s
# Step 00310/00750 | Train loss: 0.645706 | LR mult: 0.5867 | Tok/s: 710 | Step time: 8.981s
# Step 00311/00750 | Train loss: 0.015890 | LR mult: 0.5853 | Tok/s: 721 | Step time: 8.974s
# Step 00312/00750 | Train loss: 0.348825 | LR mult: 0.5840 | Tok/s: 703 | Step time: 8.971s
# Step 00313/00750 | Train loss: 0.605187 | LR mult: 0.5827 | Tok/s: 689 | Step time: 8.974s
# Step 00314/00750 | Train loss: 0.366439 | LR mult: 0.5813 | Tok/s: 684 | Step time: 8.946s
# Step 00315/00750 | Train loss: 0.614680 | LR mult: 0.5800 | Tok/s: 708 | Step time: 8.937s
# Step 00316/00750 | Train loss: 0.525675 | LR mult: 0.5787 | Tok/s: 731 | Step time: 8.954s
# Step 00317/00750 | Train loss: 1.184258 | LR mult: 0.5773 | Tok/s: 638 | Step time: 8.902s
# Step 00318/00750 | Train loss: 0.057082 | LR mult: 0.5760 | Tok/s: 642 | Step time: 8.887s
# Step 00319/00750 | Train loss: 0.323769 | LR mult: 0.5747 | Tok/s: 766 | Step time: 8.959s
# Step 00320/00750 | Train loss: 0.889428 | LR mult: 0.5733 | Tok/s: 768 | Step time: 9.022s
# Step 00321/00750 | Train loss: 1.299128 | LR mult: 0.5720 | Tok/s: 749 | Step time: 9.078s
# Step 00322/00750 | Train loss: 0.453033 | LR mult: 0.5707 | Tok/s: 785 | Step time: 9.123s
# Step 00323/00750 | Train loss: 0.520044 | LR mult: 0.5693 | Tok/s: 708 | Step time: 9.102s
# Step 00324/00750 | Train loss: 0.024775 | LR mult: 0.5680 | Tok/s: 720 | Step time: 9.090s
# Step 00325/00750 | Train loss: 1.091806 | LR mult: 0.5667 | Tok/s: 755 | Step time: 9.129s
# Step 00326/00750 | Train loss: 0.524998 | LR mult: 0.5653 | Tok/s: 581 | Step time: 9.036s
# Step 00327/00750 | Train loss: 0.018913 | LR mult: 0.5640 | Tok/s: 664 | Step time: 8.999s
# Step 00328/00750 | Train loss: 0.934359 | LR mult: 0.5627 | Tok/s: 707 | Step time: 8.990s
# Step 00329/00750 | Train loss: 0.068087 | LR mult: 0.5613 | Tok/s: 759 | Step time: 9.047s
# Step 00330/00750 | Train loss: 0.627372 | LR mult: 0.5600 | Tok/s: 833 | Step time: 9.132s
# Step 00331/00750 | Train loss: 0.984080 | LR mult: 0.5587 | Tok/s: 698 | Step time: 9.097s
# Step 00332/00750 | Train loss: 0.512007 | LR mult: 0.5573 | Tok/s: 645 | Step time: 9.044s
# Step 00333/00750 | Train loss: 0.877947 | LR mult: 0.5560 | Tok/s: 658 | Step time: 9.007s
# Step 00334/00750 | Train loss: 0.549642 | LR mult: 0.5547 | Tok/s: 728 | Step time: 8.997s
# Step 00335/00750 | Train loss: 1.844902 | LR mult: 0.5533 | Tok/s: 777 | Step time: 9.041s
# Step 00336/00750 | Train loss: 0.284980 | LR mult: 0.5520 | Tok/s: 632 | Step time: 8.986s
# Step 00337/00750 | Train loss: 0.676874 | LR mult: 0.5507 | Tok/s: 804 | Step time: 9.080s
# Step 00338/00750 | Train loss: 0.205997 | LR mult: 0.5493 | Tok/s: 731 | Step time: 9.100s
# Step 00339/00750 | Train loss: 0.638817 | LR mult: 0.5480 | Tok/s: 699 | Step time: 9.088s
# Step 00340/00750 | Train loss: 0.248076 | LR mult: 0.5467 | Tok/s: 725 | Step time: 9.093s
# Step 00341/00750 | Train loss: 1.208777 | LR mult: 0.5453 | Tok/s: 656 | Step time: 9.036s
# Step 00342/00750 | Train loss: 1.009632 | LR mult: 0.5440 | Tok/s: 708 | Step time: 9.038s
# Step 00343/00750 | Train loss: 0.565712 | LR mult: 0.5427 | Tok/s: 699 | Step time: 9.023s
# Step 00344/00750 | Train loss: 0.751128 | LR mult: 0.5413 | Tok/s: 785 | Step time: 9.071s
# Step 00345/00750 | Train loss: 0.143271 | LR mult: 0.5400 | Tok/s: 677 | Step time: 9.041s
# Step 00346/00750 | Train loss: 0.319096 | LR mult: 0.5387 | Tok/s: 708 | Step time: 9.016s
# Step 00347/00750 | Train loss: 0.104674 | LR mult: 0.5373 | Tok/s: 795 | Step time: 9.061s
# Step 00348/00750 | Train loss: 0.242217 | LR mult: 0.5360 | Tok/s: 760 | Step time: 9.086s
# Step 00349/00750 | Train loss: 0.023165 | LR mult: 0.5347 | Tok/s: 807 | Step time: 9.153s
# Step 00350/00750 | Train loss: 0.108940 | LR mult: 0.5333 | Tok/s: 666 | Step time: 9.126s
# Step 00351/00750 | Train loss: 1.898059 | LR mult: 0.5320 | Tok/s: 730 | Step time: 9.154s
# Step 00352/00750 | Train loss: 0.216456 | LR mult: 0.5307 | Tok/s: 686 | Step time: 9.133s
# Step 00353/00750 | Train loss: 0.619793 | LR mult: 0.5293 | Tok/s: 824 | Step time: 9.204s
# Step 00354/00750 | Train loss: 0.082363 | LR mult: 0.5280 | Tok/s: 672 | Step time: 9.151s
# Step 00355/00750 | Train loss: 0.160451 | LR mult: 0.5267 | Tok/s: 708 | Step time: 9.121s
# Step 00356/00750 | Train loss: 0.727704 | LR mult: 0.5253 | Tok/s: 778 | Step time: 9.159s
# Step 00357/00750 | Train loss: 0.790790 | LR mult: 0.5240 | Tok/s: 731 | Step time: 9.186s
# Step 00358/00750 | Train loss: 0.084758 | LR mult: 0.5227 | Tok/s: 667 | Step time: 9.142s
# Step 00359/00750 | Train loss: 0.668825 | LR mult: 0.5213 | Tok/s: 783 | Step time: 9.184s
# Step 00360/00750 | Train loss: 0.439748 | LR mult: 0.5200 | Tok/s: 609 | Step time: 9.091s
# Step 00361/00750 | Train loss: 0.629574 | LR mult: 0.5187 | Tok/s: 719 | Step time: 9.099s
# Step 00362/00750 | Train loss: 0.134898 | LR mult: 0.5173 | Tok/s: 593 | Step time: 9.040s
# Step 00363/00750 | Train loss: 0.156360 | LR mult: 0.5160 | Tok/s: 715 | Step time: 9.031s
# Step 00364/00750 | Train loss: 0.035173 | LR mult: 0.5147 | Tok/s: 781 | Step time: 9.103s
# Step 00365/00750 | Train loss: 0.017319 | LR mult: 0.5133 | Tok/s: 730 | Step time: 9.110s
# Step 00366/00750 | Train loss: 1.523358 | LR mult: 0.5120 | Tok/s: 707 | Step time: 9.107s
# Step 00367/00750 | Train loss: 0.428922 | LR mult: 0.5107 | Tok/s: 772 | Step time: 9.142s
# Step 00368/00750 | Train loss: 0.516575 | LR mult: 0.5093 | Tok/s: 699 | Step time: 9.094s
# Step 00369/00750 | Train loss: 0.075456 | LR mult: 0.5080 | Tok/s: 610 | Step time: 9.025s
# Step 00370/00750 | Train loss: 0.086495 | LR mult: 0.5067 | Tok/s: 618 | Step time: 8.974s
# Step 00371/00750 | Train loss: 0.278220 | LR mult: 0.5053 | Tok/s: 752 | Step time: 9.019s
# Step 00372/00750 | Train loss: 0.075677 | LR mult: 0.5040 | Tok/s: 646 | Step time: 8.993s
# Step 00373/00750 | Train loss: 0.067936 | LR mult: 0.5027 | Tok/s: 637 | Step time: 8.931s
# Step 00374/00750 | Train loss: 0.022399 | LR mult: 0.5013 | Tok/s: 766 | Step time: 8.970s
# Step 00375/00750 | Train loss: 1.011180 | LR mult: 0.5000 | Tok/s: 687 | Step time: 8.951s
# Step 00376/00750 | Train loss: 0.091083 | LR mult: 0.4987 | Tok/s: 706 | Step time: 8.950s
# Step 00377/00750 | Train loss: 0.874537 | LR mult: 0.4973 | Tok/s: 633 | Step time: 8.905s
# Step 00378/00750 | Train loss: 0.014898 | LR mult: 0.4960 | Tok/s: 721 | Step time: 8.945s
# Step 00379/00750 | Train loss: 1.632764 | LR mult: 0.4947 | Tok/s: 688 | Step time: 8.920s
# Step 00380/00750 | Train loss: 0.019006 | LR mult: 0.4933 | Tok/s: 668 | Step time: 8.903s
# Step 00381/00750 | Train loss: 0.586534 | LR mult: 0.4920 | Tok/s: 742 | Step time: 8.976s
# Step 00382/00750 | Train loss: 0.083221 | LR mult: 0.4907 | Tok/s: 737 | Step time: 9.010s
# Step 00383/00750 | Train loss: 0.077917 | LR mult: 0.4893 | Tok/s: 815 | Step time: 9.118s
# Step 00384/00750 | Train loss: 0.128940 | LR mult: 0.4880 | Tok/s: 676 | Step time: 9.087s
# Step 00385/00750 | Train loss: 0.730449 | LR mult: 0.4867 | Tok/s: 713 | Step time: 9.083s
# Step 00386/00750 | Train loss: 0.018168 | LR mult: 0.4853 | Tok/s: 752 | Step time: 9.093s
# Step 00387/00750 | Train loss: 0.308529 | LR mult: 0.4840 | Tok/s: 683 | Step time: 9.060s
# Step 00388/00750 | Train loss: 0.062888 | LR mult: 0.4827 | Tok/s: 752 | Step time: 9.109s
# Step 00389/00750 | Train loss: 1.364325 | LR mult: 0.4813 | Tok/s: 728 | Step time: 9.132s
# Step 00390/00750 | Train loss: 0.046026 | LR mult: 0.4800 | Tok/s: 620 | Step time: 9.067s
# Step 00391/00750 | Train loss: 0.417798 | LR mult: 0.4787 | Tok/s: 697 | Step time: 9.052s
# Step 00392/00750 | Train loss: 0.179615 | LR mult: 0.4773 | Tok/s: 591 | Step time: 8.966s
# Step 00393/00750 | Train loss: 1.138830 | LR mult: 0.4760 | Tok/s: 712 | Step time: 8.982s
# Step 00394/00750 | Train loss: 0.983028 | LR mult: 0.4747 | Tok/s: 687 | Step time: 8.957s
# Step 00395/00750 | Train loss: 0.063222 | LR mult: 0.4733 | Tok/s: 604 | Step time: 8.929s
# Step 00396/00750 | Train loss: 0.078043 | LR mult: 0.4720 | Tok/s: 639 | Step time: 8.890s
# Step 00397/00750 | Train loss: 0.592664 | LR mult: 0.4707 | Tok/s: 749 | Step time: 8.929s
# Step 00398/00750 | Train loss: 0.343771 | LR mult: 0.4693 | Tok/s: 571 | Step time: 8.858s
# Step 00399/00750 | Train loss: 0.966904 | LR mult: 0.4680 | Tok/s: 694 | Step time: 8.873s
# Step 00400 | Validation loss: 0.367701
# Step 00400/00750 | Train loss: 0.338092 | LR mult: 0.4667 | Tok/s: 503 | Step time: 9.404s
# Step 00401/00750 | Train loss: 0.253084 | LR mult: 0.4653 | Tok/s: 782 | Step time: 9.408s
# Step 00402/00750 | Train loss: 0.146349 | LR mult: 0.4640 | Tok/s: 660 | Step time: 9.346s
# Step 00403/00750 | Train loss: 0.114266 | LR mult: 0.4627 | Tok/s: 718 | Step time: 9.291s
# Step 00404/00750 | Train loss: 0.374806 | LR mult: 0.4613 | Tok/s: 584 | Step time: 9.198s
# Step 00405/00750 | Train loss: 0.175722 | LR mult: 0.4600 | Tok/s: 713 | Step time: 9.186s
# Step 00406/00750 | Train loss: 0.905663 | LR mult: 0.4587 | Tok/s: 720 | Step time: 9.175s
# Step 00407/00750 | Train loss: 1.107764 | LR mult: 0.4573 | Tok/s: 711 | Step time: 9.149s
# Step 00408/00750 | Train loss: 0.803422 | LR mult: 0.4560 | Tok/s: 700 | Step time: 9.116s
# Step 00409/00750 | Train loss: 0.252132 | LR mult: 0.4547 | Tok/s: 654 | Step time: 9.054s
# Step 00410/00750 | Train loss: 0.015319 | LR mult: 0.4533 | Tok/s: 696 | Step time: 9.036s
# Step 00411/00750 | Train loss: 0.759940 | LR mult: 0.4520 | Tok/s: 821 | Step time: 9.123s
# Step 00412/00750 | Train loss: 0.179773 | LR mult: 0.4507 | Tok/s: 813 | Step time: 9.213s
# Step 00413/00750 | Train loss: 0.078519 | LR mult: 0.4493 | Tok/s: 616 | Step time: 9.133s
# Step 00414/00750 | Train loss: 0.383739 | LR mult: 0.4480 | Tok/s: 695 | Step time: 9.111s
# Step 00415/00750 | Train loss: 0.244897 | LR mult: 0.4467 | Tok/s: 675 | Step time: 9.095s
# Step 00416/00750 | Train loss: 0.368422 | LR mult: 0.4453 | Tok/s: 671 | Step time: 9.042s
# Step 00417/00750 | Train loss: 0.196986 | LR mult: 0.4440 | Tok/s: 654 | Step time: 8.999s
# Step 00418/00750 | Train loss: 0.362610 | LR mult: 0.4427 | Tok/s: 668 | Step time: 8.983s
# Step 00419/00750 | Train loss: 0.750982 | LR mult: 0.4413 | Tok/s: 725 | Step time: 9.007s
# Step 00420/00750 | Train loss: 0.113598 | LR mult: 0.4400 | Tok/s: 774 | Step time: 9.053s
# Step 00421/00750 | Train loss: 1.317373 | LR mult: 0.4387 | Tok/s: 686 | Step time: 9.024s
# Step 00422/00750 | Train loss: 0.317992 | LR mult: 0.4373 | Tok/s: 685 | Step time: 9.005s
# Step 00423/00750 | Train loss: 0.352807 | LR mult: 0.4360 | Tok/s: 702 | Step time: 9.018s
# Step 00424/00750 | Train loss: 0.012309 | LR mult: 0.4347 | Tok/s: 688 | Step time: 9.003s
# Step 00425/00750 | Train loss: 0.296342 | LR mult: 0.4333 | Tok/s: 736 | Step time: 9.018s
# Step 00426/00750 | Train loss: 0.190034 | LR mult: 0.4320 | Tok/s: 693 | Step time: 9.000s
# Step 00427/00750 | Train loss: 0.164657 | LR mult: 0.4307 | Tok/s: 596 | Step time: 8.941s
# Step 00428/00750 | Train loss: 0.258238 | LR mult: 0.4293 | Tok/s: 634 | Step time: 8.893s
# Step 00429/00750 | Train loss: 0.069305 | LR mult: 0.4280 | Tok/s: 676 | Step time: 8.877s
# Step 00430/00750 | Train loss: 0.500769 | LR mult: 0.4267 | Tok/s: 801 | Step time: 8.983s
# Step 00431/00750 | Train loss: 0.305349 | LR mult: 0.4253 | Tok/s: 715 | Step time: 8.992s
# Step 00432/00750 | Train loss: 0.063442 | LR mult: 0.4240 | Tok/s: 680 | Step time: 8.972s
# Step 00433/00750 | Train loss: 1.699660 | LR mult: 0.4227 | Tok/s: 767 | Step time: 9.034s
# Step 00434/00750 | Train loss: 0.107464 | LR mult: 0.4213 | Tok/s: 796 | Step time: 9.092s
# Step 00435/00750 | Train loss: 0.073608 | LR mult: 0.4200 | Tok/s: 612 | Step time: 9.039s
# Step 00436/00750 | Train loss: 0.457963 | LR mult: 0.4187 | Tok/s: 711 | Step time: 9.063s
# Step 00437/00750 | Train loss: 0.073346 | LR mult: 0.4173 | Tok/s: 691 | Step time: 9.051s
# Step 00438/00750 | Train loss: 0.114383 | LR mult: 0.4160 | Tok/s: 677 | Step time: 9.030s
# Step 00439/00750 | Train loss: 0.087808 | LR mult: 0.4147 | Tok/s: 710 | Step time: 9.035s
# Step 00440/00750 | Train loss: 0.406498 | LR mult: 0.4133 | Tok/s: 631 | Step time: 8.978s
# Step 00441/00750 | Train loss: 0.052069 | LR mult: 0.4120 | Tok/s: 596 | Step time: 8.896s
# Step 00442/00750 | Train loss: 0.864883 | LR mult: 0.4107 | Tok/s: 700 | Step time: 8.908s
# Step 00443/00750 | Train loss: 0.091205 | LR mult: 0.4093 | Tok/s: 559 | Step time: 8.838s
# Step 00444/00750 | Train loss: 0.656195 | LR mult: 0.4080 | Tok/s: 813 | Step time: 8.954s
# Step 00445/00750 | Train loss: 0.618799 | LR mult: 0.4067 | Tok/s: 664 | Step time: 8.918s
# Step 00446/00750 | Train loss: 0.095629 | LR mult: 0.4053 | Tok/s: 661 | Step time: 8.902s
# Step 00447/00750 | Train loss: 0.098018 | LR mult: 0.4040 | Tok/s: 737 | Step time: 8.974s
# Step 00448/00750 | Train loss: 0.347700 | LR mult: 0.4027 | Tok/s: 688 | Step time: 8.962s
# Step 00449/00750 | Train loss: 0.531148 | LR mult: 0.4013 | Tok/s: 698 | Step time: 8.940s
# Step 00450/00750 | Train loss: 0.032080 | LR mult: 0.4000 | Tok/s: 594 | Step time: 8.873s
# Step 00451/00750 | Train loss: 0.182378 | LR mult: 0.3987 | Tok/s: 708 | Step time: 8.881s
# Step 00452/00750 | Train loss: 0.151129 | LR mult: 0.3973 | Tok/s: 681 | Step time: 8.862s
# Step 00453/00750 | Train loss: 0.030066 | LR mult: 0.3960 | Tok/s: 741 | Step time: 8.909s
# Step 00454/00750 | Train loss: 0.559464 | LR mult: 0.3947 | Tok/s: 714 | Step time: 8.920s
# Step 00455/00750 | Train loss: 0.100285 | LR mult: 0.3933 | Tok/s: 661 | Step time: 8.913s
# Step 00456/00750 | Train loss: 0.332174 | LR mult: 0.3920 | Tok/s: 707 | Step time: 8.910s
# Step 00457/00750 | Train loss: 0.038928 | LR mult: 0.3907 | Tok/s: 612 | Step time: 8.849s
# Step 00458/00750 | Train loss: 0.230975 | LR mult: 0.3893 | Tok/s: 684 | Step time: 8.825s
# Step 00459/00750 | Train loss: 0.052770 | LR mult: 0.3880 | Tok/s: 657 | Step time: 8.817s
# Step 00460/00750 | Train loss: 0.063570 | LR mult: 0.3867 | Tok/s: 606 | Step time: 8.766s
# Step 00461/00750 | Train loss: 0.111134 | LR mult: 0.3853 | Tok/s: 679 | Step time: 8.779s
# Step 00462/00750 | Train loss: 0.010282 | LR mult: 0.3840 | Tok/s: 703 | Step time: 8.810s
# Step 00463/00750 | Train loss: 0.094828 | LR mult: 0.3827 | Tok/s: 706 | Step time: 8.824s
# Step 00464/00750 | Train loss: 0.074179 | LR mult: 0.3813 | Tok/s: 623 | Step time: 8.793s
# Step 00465/00750 | Train loss: 0.065972 | LR mult: 0.3800 | Tok/s: 683 | Step time: 8.808s
# Step 00466/00750 | Train loss: 0.364694 | LR mult: 0.3787 | Tok/s: 721 | Step time: 8.828s
# Step 00467/00750 | Train loss: 0.512496 | LR mult: 0.3773 | Tok/s: 747 | Step time: 8.891s
# Step 00468/00750 | Train loss: 0.042967 | LR mult: 0.3760 | Tok/s: 669 | Step time: 8.886s
# Step 00469/00750 | Train loss: 0.066586 | LR mult: 0.3747 | Tok/s: 809 | Step time: 8.983s
# Step 00470/00750 | Train loss: 0.779150 | LR mult: 0.3733 | Tok/s: 659 | Step time: 8.961s
# Step 00471/00750 | Train loss: 0.172715 | LR mult: 0.3720 | Tok/s: 627 | Step time: 8.908s
# Step 00472/00750 | Train loss: 0.057271 | LR mult: 0.3707 | Tok/s: 681 | Step time: 8.916s
# Step 00473/00750 | Train loss: 0.948459 | LR mult: 0.3693 | Tok/s: 679 | Step time: 8.919s
# Step 00474/00750 | Train loss: 0.140264 | LR mult: 0.3680 | Tok/s: 749 | Step time: 8.964s
# Step 00475/00750 | Train loss: 0.135688 | LR mult: 0.3667 | Tok/s: 701 | Step time: 8.984s
# Step 00476/00750 | Train loss: 0.179291 | LR mult: 0.3653 | Tok/s: 729 | Step time: 8.997s
# Step 00477/00750 | Train loss: 0.076449 | LR mult: 0.3640 | Tok/s: 699 | Step time: 9.000s
# Step 00478/00750 | Train loss: 0.075724 | LR mult: 0.3627 | Tok/s: 628 | Step time: 8.959s
# Step 00479/00750 | Train loss: 0.465084 | LR mult: 0.3613 | Tok/s: 690 | Step time: 8.975s
# Step 00480/00750 | Train loss: 0.712006 | LR mult: 0.3600 | Tok/s: 741 | Step time: 8.993s
# Step 00481/00750 | Train loss: 0.086177 | LR mult: 0.3587 | Tok/s: 731 | Step time: 9.011s
# Step 00482/00750 | Train loss: 0.080551 | LR mult: 0.3573 | Tok/s: 716 | Step time: 9.008s
# Step 00483/00750 | Train loss: 1.540293 | LR mult: 0.3560 | Tok/s: 671 | Step time: 8.986s
# Step 00484/00750 | Train loss: 0.102044 | LR mult: 0.3547 | Tok/s: 656 | Step time: 8.957s
# Step 00485/00750 | Train loss: 0.874807 | LR mult: 0.3533 | Tok/s: 687 | Step time: 8.953s
# Step 00486/00750 | Train loss: 0.666169 | LR mult: 0.3520 | Tok/s: 665 | Step time: 8.931s
# Step 00487/00750 | Train loss: 0.017737 | LR mult: 0.3507 | Tok/s: 736 | Step time: 8.959s
# Step 00488/00750 | Train loss: 0.304303 | LR mult: 0.3493 | Tok/s: 680 | Step time: 8.945s
# Step 00489/00750 | Train loss: 0.211949 | LR mult: 0.3480 | Tok/s: 613 | Step time: 8.888s
# Step 00490/00750 | Train loss: 0.170067 | LR mult: 0.3467 | Tok/s: 665 | Step time: 8.859s
# Step 00491/00750 | Train loss: 0.023384 | LR mult: 0.3453 | Tok/s: 672 | Step time: 8.842s
# Step 00492/00750 | Train loss: 0.615090 | LR mult: 0.3440 | Tok/s: 713 | Step time: 8.849s
# Step 00493/00750 | Train loss: 0.014754 | LR mult: 0.3427 | Tok/s: 718 | Step time: 8.886s
# Step 00494/00750 | Train loss: 0.374496 | LR mult: 0.3413 | Tok/s: 754 | Step time: 8.913s
# Step 00495/00750 | Train loss: 0.078945 | LR mult: 0.3400 | Tok/s: 684 | Step time: 8.910s
# Step 00496/00750 | Train loss: 0.067836 | LR mult: 0.3387 | Tok/s: 728 | Step time: 8.929s
# Step 00497/00750 | Train loss: 0.528076 | LR mult: 0.3373 | Tok/s: 667 | Step time: 8.906s
# Step 00498/00750 | Train loss: 0.080581 | LR mult: 0.3360 | Tok/s: 656 | Step time: 8.888s
# Step 00499/00750 | Train loss: 0.405148 | LR mult: 0.3347 | Tok/s: 753 | Step time: 8.944s
# Step 00500 | Validation loss: 0.303871
# Step 00500/00750 | Train loss: 0.040155 | LR mult: 0.3333 | Tok/s: 447 | Step time: 9.358s
# Step 00501/00750 | Train loss: 0.462932 | LR mult: 0.3320 | Tok/s: 654 | Step time: 9.276s
# Step 00502/00750 | Train loss: 0.213785 | LR mult: 0.3307 | Tok/s: 721 | Step time: 9.250s
# Step 00503/00750 | Train loss: 0.345491 | LR mult: 0.3293 | Tok/s: 710 | Step time: 9.210s
# Step 00504/00750 | Train loss: 1.600227 | LR mult: 0.3280 | Tok/s: 718 | Step time: 9.209s
# Step 00505/00750 | Train loss: 0.052974 | LR mult: 0.3267 | Tok/s: 772 | Step time: 9.233s
# Step 00506/00750 | Train loss: 0.338568 | LR mult: 0.3253 | Tok/s: 740 | Step time: 9.247s
# Step 00507/00750 | Train loss: 0.134880 | LR mult: 0.3240 | Tok/s: 807 | Step time: 9.297s
# Step 00508/00750 | Train loss: 0.056309 | LR mult: 0.3227 | Tok/s: 682 | Step time: 9.270s
# Step 00509/00750 | Train loss: 1.868225 | LR mult: 0.3213 | Tok/s: 759 | Step time: 9.276s
# Step 00510/00750 | Train loss: 0.573424 | LR mult: 0.3200 | Tok/s: 762 | Step time: 9.308s
# Step 00511/00750 | Train loss: 0.007530 | LR mult: 0.3187 | Tok/s: 731 | Step time: 9.292s
# Step 00512/00750 | Train loss: 0.098967 | LR mult: 0.3173 | Tok/s: 686 | Step time: 9.242s
# Step 00513/00750 | Train loss: 0.063502 | LR mult: 0.3160 | Tok/s: 686 | Step time: 9.207s
# Step 00514/00750 | Train loss: 0.621192 | LR mult: 0.3147 | Tok/s: 721 | Step time: 9.196s
# Step 00515/00750 | Train loss: 0.061793 | LR mult: 0.3133 | Tok/s: 703 | Step time: 9.185s
# Step 00516/00750 | Train loss: 0.115749 | LR mult: 0.3120 | Tok/s: 628 | Step time: 9.126s
# Step 00517/00750 | Train loss: 0.191051 | LR mult: 0.3107 | Tok/s: 682 | Step time: 9.089s
# Step 00518/00750 | Train loss: 0.061776 | LR mult: 0.3093 | Tok/s: 717 | Step time: 9.087s
# Step 00519/00750 | Train loss: 0.013633 | LR mult: 0.3080 | Tok/s: 682 | Step time: 9.059s
# Step 00520/00750 | Train loss: 0.083421 | LR mult: 0.3067 | Tok/s: 628 | Step time: 8.997s
# ...
# Step 00576/00750 | Train loss: 0.087846 | LR mult: 0.2320 | Tok/s: 689 | Step time: 8.937s
# Step 00577/00750 | Train loss: 0.137545 | LR mult: 0.2307 | Tok/s: 654 | Step time: 8.905s
# Step 00578/00750 | Train loss: 0.086633 | LR mult: 0.2293 | Tok/s: 739 | Step time: 8.921s
# Step 00579/00750 | Train loss: 0.090366 | LR mult: 0.2280 | Tok/s: 604 | Step time: 8.856s
# Step 00580/00750 | Train loss: 0.411052 | LR mult: 0.2267 | Tok/s: 656 | Step time: 8.823s
# Step 00581/00750 | Train loss: 0.013419 | LR mult: 0.2253 | Tok/s: 731 | Step time: 8.862s
# Step 00582/00750 | Train loss: 0.067669 | LR mult: 0.2240 | Tok/s: 676 | Step time: 8.854s
# Step 00583/00750 | Train loss: 0.811554 | LR mult: 0.2227 | Tok/s: 718 | Step time: 8.867s
# Step 00584/00750 | Train loss: 0.023342 | LR mult: 0.2213 | Tok/s: 668 | Step time: 8.851s
# Step 00585/00750 | Train loss: 0.024038 | LR mult: 0.2200 | Tok/s: 685 | Step time: 8.843s
# Step 00586/00750 | Train loss: 0.071475 | LR mult: 0.2187 | Tok/s: 672 | Step time: 8.828s
# Step 00587/00750 | Train loss: 0.025064 | LR mult: 0.2173 | Tok/s: 731 | Step time: 8.854s
# Step 00588/00750 | Train loss: 0.075313 | LR mult: 0.2160 | Tok/s: 699 | Step time: 8.853s
# Step 00589/00750 | Train loss: 0.009222 | LR mult: 0.2147 | Tok/s: 653 | Step time: 8.827s
# Step 00590/00750 | Train loss: 0.046984 | LR mult: 0.2133 | Tok/s: 694 | Step time: 8.850s
# Step 00591/00750 | Train loss: 0.092444 | LR mult: 0.2120 | Tok/s: 670 | Step time: 8.862s
# Step 00592/00750 | Train loss: 0.366070 | LR mult: 0.2107 | Tok/s: 709 | Step time: 8.895s
# Step 00593/00750 | Train loss: 0.085187 | LR mult: 0.2093 | Tok/s: 649 | Step time: 8.861s
# Step 00594/00750 | Train loss: 0.327847 | LR mult: 0.2080 | Tok/s: 582 | Step time: 8.800s
# Step 00595/00750 | Train loss: 0.084877 | LR mult: 0.2067 | Tok/s: 637 | Step time: 8.770s
# Step 00596/00750 | Train loss: 0.193792 | LR mult: 0.2053 | Tok/s: 738 | Step time: 8.820s
# Step 00597/00750 | Train loss: 0.541018 | LR mult: 0.2040 | Tok/s: 696 | Step time: 8.816s
# Step 00598/00750 | Train loss: 0.113945 | LR mult: 0.2027 | Tok/s: 671 | Step time: 8.806s
# Step 00599/00750 | Train loss: 0.540933 | LR mult: 0.2013 | Tok/s: 682 | Step time: 8.794s
# Step 00600 | Validation loss: 0.203977
# Step 00600/00750 | Train loss: 0.738204 | LR mult: 0.2000 | Tok/s: 472 | Step time: 9.218s
# Step 00601/00750 | Train loss: 0.495527 | LR mult: 0.1987 | Tok/s: 597 | Step time: 9.124s
# Step 00602/00750 | Train loss: 0.390880 | LR mult: 0.1973 | Tok/s: 685 | Step time: 9.091s
# Step 00603/00750 | Train loss: 0.556748 | LR mult: 0.1960 | Tok/s: 707 | Step time: 9.098s
# Step 00604/00750 | Train loss: 0.644389 | LR mult: 0.1947 | Tok/s: 716 | Step time: 9.071s
# Step 00605/00750 | Train loss: 0.034217 | LR mult: 0.1933 | Tok/s: 744 | Step time: 9.077s
# Step 00606/00750 | Train loss: 0.745969 | LR mult: 0.1920 | Tok/s: 640 | Step time: 9.015s
# Step 00607/00750 | Train loss: 0.084831 | LR mult: 0.1907 | Tok/s: 727 | Step time: 9.012s
# Step 00608/00750 | Train loss: 0.377520 | LR mult: 0.1893 | Tok/s: 812 | Step time: 9.108s
# Step 00609/00750 | Train loss: 0.091323 | LR mult: 0.1880 | Tok/s: 692 | Step time: 9.081s
# Step 00610/00750 | Train loss: 1.358087 | LR mult: 0.1867 | Tok/s: 718 | Step time: 9.083s
# Step 00611/00750 | Train loss: 0.534574 | LR mult: 0.1853 | Tok/s: 680 | Step time: 9.038s
# Step 00612/00750 | Train loss: 0.035510 | LR mult: 0.1840 | Tok/s: 717 | Step time: 9.063s
# Step 00613/00750 | Train loss: 0.048884 | LR mult: 0.1827 | Tok/s: 793 | Step time: 9.144s
# Step 00614/00750 | Train loss: 0.290200 | LR mult: 0.1813 | Tok/s: 632 | Step time: 9.079s
# Step 00615/00750 | Train loss: 0.015647 | LR mult: 0.1800 | Tok/s: 690 | Step time: 9.042s
# Step 00616/00750 | Train loss: 0.216415 | LR mult: 0.1787 | Tok/s: 746 | Step time: 9.059s
# Step 00617/00750 | Train loss: 0.029789 | LR mult: 0.1773 | Tok/s: 785 | Step time: 9.123s
# Step 00618/00750 | Train loss: 0.011386 | LR mult: 0.1760 | Tok/s: 739 | Step time: 9.129s
# Step 00619/00750 | Train loss: 0.186998 | LR mult: 0.1747 | Tok/s: 657 | Step time: 9.088s
# Step 00620/00750 | Train loss: 0.074527 | LR mult: 0.1733 | Tok/s: 699 | Step time: 9.062s
# Step 00621/00750 | Train loss: 0.096368 | LR mult: 0.1720 | Tok/s: 739 | Step time: 9.096s
# Step 00622/00750 | Train loss: 0.781416 | LR mult: 0.1707 | Tok/s: 660 | Step time: 9.077s
# Step 00623/00750 | Train loss: 0.092306 | LR mult: 0.1693 | Tok/s: 651 | Step time: 9.036s
# Step 00624/00750 | Train loss: 0.153702 | LR mult: 0.1680 | Tok/s: 652 | Step time: 9.005s
# Step 00625/00750 | Train loss: 0.338806 | LR mult: 0.1667 | Tok/s: 763 | Step time: 9.060s
# Step 00626/00750 | Train loss: 0.009348 | LR mult: 0.1653 | Tok/s: 688 | Step time: 9.062s
# Step 00627/00750 | Train loss: 0.335349 | LR mult: 0.1640 | Tok/s: 640 | Step time: 9.009s
# Step 00628/00750 | Train loss: 0.013747 | LR mult: 0.1627 | Tok/s: 733 | Step time: 9.040s
# Step 00629/00750 | Train loss: 0.392821 | LR mult: 0.1613 | Tok/s: 660 | Step time: 8.999s
# Step 00630/00750 | Train loss: 0.365191 | LR mult: 0.1600 | Tok/s: 734 | Step time: 9.014s
# Step 00631/00750 | Train loss: 0.642506 | LR mult: 0.1587 | Tok/s: 617 | Step time: 8.947s
# Step 00632/00750 | Train loss: 0.020776 | LR mult: 0.1573 | Tok/s: 706 | Step time: 8.939s
# Step 00633/00750 | Train loss: 0.038751 | LR mult: 0.1560 | Tok/s: 735 | Step time: 8.963s
# Step 00634/00750 | Train loss: 0.007487 | LR mult: 0.1547 | Tok/s: 651 | Step time: 8.925s
# Step 00635/00750 | Train loss: 0.081602 | LR mult: 0.1533 | Tok/s: 661 | Step time: 8.904s
# Step 00636/00750 | Train loss: 0.071519 | LR mult: 0.1520 | Tok/s: 691 | Step time: 8.897s
# Step 00637/00750 | Train loss: 0.828365 | LR mult: 0.1507 | Tok/s: 725 | Step time: 8.934s
# Step 00638/00750 | Train loss: 0.191815 | LR mult: 0.1493 | Tok/s: 656 | Step time: 8.895s
# Step 00639/00750 | Train loss: 0.745127 | LR mult: 0.1480 | Tok/s: 737 | Step time: 8.945s
# Step 00640/00750 | Train loss: 0.177990 | LR mult: 0.1467 | Tok/s: 686 | Step time: 8.936s
# Step 00641/00750 | Train loss: 0.735847 | LR mult: 0.1453 | Tok/s: 681 | Step time: 8.945s
# Step 00642/00750 | Train loss: 0.046071 | LR mult: 0.1440 | Tok/s: 731 | Step time: 8.950s
# Step 00643/00750 | Train loss: 0.019866 | LR mult: 0.1427 | Tok/s: 668 | Step time: 8.920s
# Step 00644/00750 | Train loss: 0.100708 | LR mult: 0.1413 | Tok/s: 760 | Step time: 8.954s
# Step 00645/00750 | Train loss: 0.222557 | LR mult: 0.1400 | Tok/s: 672 | Step time: 8.959s
# Step 00646/00750 | Train loss: 0.154203 | LR mult: 0.1387 | Tok/s: 686 | Step time: 8.952s
# Step 00647/00750 | Train loss: 0.369724 | LR mult: 0.1373 | Tok/s: 735 | Step time: 8.993s
# Step 00648/00750 | Train loss: 0.182791 | LR mult: 0.1360 | Tok/s: 777 | Step time: 9.037s
# Step 00649/00750 | Train loss: 2.659817 | LR mult: 0.1347 | Tok/s: 676 | Step time: 9.028s
# Step 00650/00750 | Train loss: 0.369966 | LR mult: 0.1333 | Tok/s: 720 | Step time: 9.051s
# Step 00651/00750 | Train loss: 0.276941 | LR mult: 0.1320 | Tok/s: 637 | Step time: 9.013s
# Step 00652/00750 | Train loss: 0.084448 | LR mult: 0.1307 | Tok/s: 646 | Step time: 8.952s
# Step 00653/00750 | Train loss: 0.464086 | LR mult: 0.1293 | Tok/s: 613 | Step time: 8.899s
# Step 00654/00750 | Train loss: 0.035116 | LR mult: 0.1280 | Tok/s: 717 | Step time: 8.920s
# Step 00655/00750 | Train loss: 0.247169 | LR mult: 0.1267 | Tok/s: 739 | Step time: 8.944s
# Step 00656/00750 | Train loss: 0.068687 | LR mult: 0.1253 | Tok/s: 611 | Step time: 8.897s
# Step 00657/00750 | Train loss: 0.416121 | LR mult: 0.1240 | Tok/s: 656 | Step time: 8.865s
# Step 00658/00750 | Train loss: 0.009584 | LR mult: 0.1227 | Tok/s: 619 | Step time: 8.829s
# Step 00659/00750 | Train loss: 0.160860 | LR mult: 0.1213 | Tok/s: 739 | Step time: 8.883s
# Step 00660/00750 | Train loss: 0.086645 | LR mult: 0.1200 | Tok/s: 672 | Step time: 8.869s
# Step 00661/00750 | Train loss: 0.311610 | LR mult: 0.1187 | Tok/s: 686 | Step time: 8.876s
# Step 00662/00750 | Train loss: 0.081387 | LR mult: 0.1173 | Tok/s: 663 | Step time: 8.867s
# Step 00663/00750 | Train loss: 0.077536 | LR mult: 0.1160 | Tok/s: 712 | Step time: 8.890s
# Step 00664/00750 | Train loss: 0.589655 | LR mult: 0.1147 | Tok/s: 737 | Step time: 8.937s
# Step 00665/00750 | Train loss: 0.206352 | LR mult: 0.1133 | Tok/s: 806 | Step time: 9.041s
# Step 00666/00750 | Train loss: 0.399121 | LR mult: 0.1120 | Tok/s: 697 | Step time: 9.026s
# Step 00667/00750 | Train loss: 0.073687 | LR mult: 0.1107 | Tok/s: 717 | Step time: 9.051s
# Step 00668/00750 | Train loss: 0.067064 | LR mult: 0.1093 | Tok/s: 629 | Step time: 9.007s
# Step 00669/00750 | Train loss: 0.078050 | LR mult: 0.1080 | Tok/s: 635 | Step time: 8.962s
# Step 00670/00750 | Train loss: 0.076262 | LR mult: 0.1067 | Tok/s: 683 | Step time: 8.950s
# Step 00671/00750 | Train loss: 0.335103 | LR mult: 0.1053 | Tok/s: 716 | Step time: 8.948s
# Step 00672/00750 | Train loss: 0.384315 | LR mult: 0.1040 | Tok/s: 755 | Step time: 9.001s
# Step 00673/00750 | Train loss: 0.562700 | LR mult: 0.1027 | Tok/s: 677 | Step time: 8.972s
# Step 00674/00750 | Train loss: 0.025576 | LR mult: 0.1013 | Tok/s: 639 | Step time: 8.920s
# Step 00675/00750 | Train loss: 1.437588 | LR mult: 0.1000 | Tok/s: 573 | Step time: 8.857s
# Step 00676/00750 | Train loss: 0.012597 | LR mult: 0.0987 | Tok/s: 698 | Step time: 8.858s
# Step 00677/00750 | Train loss: 0.034626 | LR mult: 0.0973 | Tok/s: 682 | Step time: 8.865s
# Step 00678/00750 | Train loss: 0.607905 | LR mult: 0.0960 | Tok/s: 690 | Step time: 8.853s
# Step 00679/00750 | Train loss: 1.075349 | LR mult: 0.0947 | Tok/s: 652 | Step time: 8.831s
# Step 00680/00750 | Train loss: 0.008907 | LR mult: 0.0933 | Tok/s: 728 | Step time: 8.854s
# Step 00681/00750 | Train loss: 0.231998 | LR mult: 0.0920 | Tok/s: 691 | Step time: 8.849s
# Step 00682/00750 | Train loss: 0.304637 | LR mult: 0.0907 | Tok/s: 669 | Step time: 8.831s
# Step 00683/00750 | Train loss: 0.067759 | LR mult: 0.0893 | Tok/s: 618 | Step time: 8.791s
# Step 00684/00750 | Train loss: 0.132868 | LR mult: 0.0880 | Tok/s: 735 | Step time: 8.831s
# Step 00685/00750 | Train loss: 0.218521 | LR mult: 0.0867 | Tok/s: 710 | Step time: 8.842s
# Step 00686/00750 | Train loss: 0.014564 | LR mult: 0.0853 | Tok/s: 720 | Step time: 8.850s
# Step 00687/00750 | Train loss: 0.155867 | LR mult: 0.0840 | Tok/s: 702 | Step time: 8.860s
# Step 00688/00750 | Train loss: 0.392325 | LR mult: 0.0827 | Tok/s: 688 | Step time: 8.875s
# Step 00689/00750 | Train loss: 0.085918 | LR mult: 0.0813 | Tok/s: 683 | Step time: 8.859s
# Step 00690/00750 | Train loss: 0.167860 | LR mult: 0.0800 | Tok/s: 708 | Step time: 8.859s
# Step 00691/00750 | Train loss: 0.155208 | LR mult: 0.0787 | Tok/s: 730 | Step time: 8.886s
# Step 00692/00750 | Train loss: 0.914344 | LR mult: 0.0773 | Tok/s: 638 | Step time: 8.841s
# Step 00693/00750 | Train loss: 0.060503 | LR mult: 0.0760 | Tok/s: 641 | Step time: 8.832s
# Step 00694/00750 | Train loss: 0.067792 | LR mult: 0.0747 | Tok/s: 766 | Step time: 8.911s
# Step 00695/00750 | Train loss: 0.415199 | LR mult: 0.0733 | Tok/s: 767 | Step time: 8.980s
# Step 00696/00750 | Train loss: 0.700634 | LR mult: 0.0720 | Tok/s: 749 | Step time: 9.040s
# Step 00697/00750 | Train loss: 0.074257 | LR mult: 0.0707 | Tok/s: 784 | Step time: 9.090s
# Step 00698/00750 | Train loss: 0.281828 | LR mult: 0.0693 | Tok/s: 707 | Step time: 9.073s
# Step 00699/00750 | Train loss: 0.010428 | LR mult: 0.0680 | Tok/s: 719 | Step time: 9.064s
# Step 00700 | Validation loss: 0.312612
# Step 00700/00750 | Train loss: 0.283978 | LR mult: 0.0667 | Tok/s: 520 | Step time: 9.536s
# Step 00701/00750 | Train loss: 0.107250 | LR mult: 0.0653 | Tok/s: 580 | Step time: 9.403s
# Step 00702/00750 | Train loss: 0.011672 | LR mult: 0.0640 | Tok/s: 663 | Step time: 9.330s
# Step 00703/00750 | Train loss: 0.565403 | LR mult: 0.0627 | Tok/s: 706 | Step time: 9.289s
# Step 00704/00750 | Train loss: 0.069249 | LR mult: 0.0613 | Tok/s: 758 | Step time: 9.317s
# Step 00705/00750 | Train loss: 0.308848 | LR mult: 0.0600 | Tok/s: 832 | Step time: 9.376s
# Step 00706/00750 | Train loss: 0.608258 | LR mult: 0.0587 | Tok/s: 697 | Step time: 9.317s
# Step 00707/00750 | Train loss: 0.116157 | LR mult: 0.0573 | Tok/s: 644 | Step time: 9.243s
# Step 00708/00750 | Train loss: 0.448341 | LR mult: 0.0560 | Tok/s: 657 | Step time: 9.187s
# Step 00709/00750 | Train loss: 0.370588 | LR mult: 0.0547 | Tok/s: 728 | Step time: 9.160s
# Step 00710/00750 | Train loss: 1.702841 | LR mult: 0.0533 | Tok/s: 777 | Step time: 9.188s
# Step 00711/00750 | Train loss: 0.068296 | LR mult: 0.0520 | Tok/s: 632 | Step time: 9.118s
# Step 00712/00750 | Train loss: 0.329461 | LR mult: 0.0507 | Tok/s: 803 | Step time: 9.199s
# Step 00713/00750 | Train loss: 0.184637 | LR mult: 0.0493 | Tok/s: 731 | Step time: 9.208s
# Step 00714/00750 | Train loss: 0.364838 | LR mult: 0.0480 | Tok/s: 699 | Step time: 9.186s
# Step 00715/00750 | Train loss: 0.029840 | LR mult: 0.0467 | Tok/s: 724 | Step time: 9.182s
# Step 00716/00750 | Train loss: 0.776308 | LR mult: 0.0453 | Tok/s: 655 | Step time: 9.116s
# Step 00717/00750 | Train loss: 0.286334 | LR mult: 0.0440 | Tok/s: 708 | Step time: 9.110s
# Step 00718/00750 | Train loss: 0.216827 | LR mult: 0.0427 | Tok/s: 698 | Step time: 9.089s
# Step 00719/00750 | Train loss: 0.372975 | LR mult: 0.0413 | Tok/s: 785 | Step time: 9.130s
# Step 00720/00750 | Train loss: 0.019731 | LR mult: 0.0400 | Tok/s: 676 | Step time: 9.094s
# Step 00721/00750 | Train loss: 0.063279 | LR mult: 0.0387 | Tok/s: 708 | Step time: 9.065s
# Step 00722/00750 | Train loss: 0.095836 | LR mult: 0.0373 | Tok/s: 794 | Step time: 9.105s
# Step 00723/00750 | Train loss: 0.047943 | LR mult: 0.0360 | Tok/s: 760 | Step time: 9.127s
# Step 00724/00750 | Train loss: 0.012303 | LR mult: 0.0347 | Tok/s: 806 | Step time: 9.191s
# Step 00725/00750 | Train loss: 0.023839 | LR mult: 0.0333 | Tok/s: 666 | Step time: 9.160s
# Step 00726/00750 | Train loss: 1.739412 | LR mult: 0.0320 | Tok/s: 730 | Step time: 9.185s
# Step 00727/00750 | Train loss: 0.065666 | LR mult: 0.0307 | Tok/s: 685 | Step time: 9.162s
# Step 00728/00750 | Train loss: 0.275952 | LR mult: 0.0293 | Tok/s: 824 | Step time: 9.230s
# Step 00729/00750 | Train loss: 0.082930 | LR mult: 0.0280 | Tok/s: 672 | Step time: 9.174s
# Step 00730/00750 | Train loss: 0.033953 | LR mult: 0.0267 | Tok/s: 708 | Step time: 9.143s
# Step 00731/00750 | Train loss: 0.411150 | LR mult: 0.0253 | Tok/s: 777 | Step time: 9.179s
# Step 00732/00750 | Train loss: 0.226237 | LR mult: 0.0240 | Tok/s: 731 | Step time: 9.206s
# Step 00733/00750 | Train loss: 0.056419 | LR mult: 0.0227 | Tok/s: 667 | Step time: 9.160s
# Step 00734/00750 | Train loss: 0.376397 | LR mult: 0.0213 | Tok/s: 782 | Step time: 9.201s
# Step 00735/00750 | Train loss: 0.065082 | LR mult: 0.0200 | Tok/s: 609 | Step time: 9.107s
# Step 00736/00750 | Train loss: 0.514678 | LR mult: 0.0187 | Tok/s: 719 | Step time: 9.114s
# Step 00737/00750 | Train loss: 0.071073 | LR mult: 0.0173 | Tok/s: 592 | Step time: 9.053s
# Step 00738/00750 | Train loss: 0.018297 | LR mult: 0.0160 | Tok/s: 714 | Step time: 9.043s
# Step 00739/00750 | Train loss: 0.011989 | LR mult: 0.0147 | Tok/s: 781 | Step time: 9.114s
# Step 00740/00750 | Train loss: 0.013989 | LR mult: 0.0133 | Tok/s: 730 | Step time: 9.120s
# Step 00741/00750 | Train loss: 0.996925 | LR mult: 0.0120 | Tok/s: 707 | Step time: 9.117s
# Step 00742/00750 | Train loss: 0.165676 | LR mult: 0.0107 | Tok/s: 772 | Step time: 9.151s
# Step 00743/00750 | Train loss: 0.178432 | LR mult: 0.0093 | Tok/s: 699 | Step time: 9.103s
# Step 00744/00750 | Train loss: 0.055600 | LR mult: 0.0080 | Tok/s: 610 | Step time: 9.034s
# Step 00745/00750 | Train loss: 0.048078 | LR mult: 0.0067 | Tok/s: 617 | Step time: 8.982s
# Step 00746/00750 | Train loss: 0.058159 | LR mult: 0.0053 | Tok/s: 752 | Step time: 9.027s
# Step 00747/00750 | Train loss: 0.072213 | LR mult: 0.0040 | Tok/s: 646 | Step time: 9.001s
# Step 00748/00750 | Train loss: 0.074774 | LR mult: 0.0027 | Tok/s: 637 | Step time: 8.938s
# Step 00749 | Validation loss: 0.406474
# Step 00749/00750 | Train loss: 0.015163 | LR mult: 0.0013 | Tok/s: 514 | Step time: 9.435s
#
# Training complete.

# %% [markdown]
# <!-- ## Save Final Model Artifacts -->

# %%
# final_dir.mkdir(parents=True, exist_ok=True)

# print(f"Saving final model checkpoint to {final_dir}...")

# # Create metadata for the checkpoint
# checkpoint_meta = {
#     "step": step,
#     "val_loss": val_loss,
#     "model_config": model.config.__dict__,
# }

# # Use the nanochat save_checkpoint function
# save_checkpoint(
#     checkpoint_dir=str(final_dir),
#     step=step, # You can use the final step number
#     model_state=model.state_dict(),
#     # We are not saving optimizer state in this simplified version
#     optimizer_state=None,
#     meta=checkpoint_meta,
# )

# # The tokenizer is a folder, so we can't save it with the checkpoint manager.
# # We'll just copy the files if they aren't already there.
# tokenizer.save_vocabulary(str(final_dir))

# print(f"Saved fine-tuned model and tokenizer to {final_dir}")

# %% [markdown]
# ## Testing Option: Save Base Model as "Fine-tuned" for Validation
#
# **UNCOMMENT THE CELL BELOW** if you want to skip training and just save the current base model as a "fine-tuned" model for testing purposes. This allows you to validate that all evaluation and demo components work before running actual training on a GPU.

# %%
# # Save the fine-tuned model after training completes (only rank 0)
# if ddp_rank == 0:
#     import shutil
#     from pathlib import Path

#     # Create directory for the fine-tuned model
#     finetuned_model_dir = Path("finetuned_model_checkpoint")
#     finetuned_model_dir.mkdir(exist_ok=True)

#     # Save model state
#     save_path = finetuned_model_dir / "model_finetuned.pt"
#     meta_path = finetuned_model_dir / "meta_finetuned.json"

#     # Unwrap DDP if necessary
#     model_to_save = base_model if ddp else model

#     torch.save(model_to_save.state_dict(), save_path)
#     print(f"✓ Fine-tuned model saved to {save_path}")

#     # Save metadata with training info
#     meta_with_training = meta.copy()
#     meta_with_training['training_info'] = {
#         'num_train_samples': len(train_dataset),
#         'num_val_samples': len(val_dataset),
#         'num_epochs': num_epochs,
#         'effective_batch_size': target_examples_per_step * ddp_world_size,
#         'final_val_loss': val_loss,
#         'world_size': ddp_world_size,
#     }

#     with open(meta_path, "w", encoding="utf-8") as f:
#         json.dump(meta_with_training, f, indent=2)
#     print(f"✓ Metadata saved to {meta_path}")

#     # Copy tokenizer files
#     tokenizer_source = base_cache / "tokenizer"
#     tokenizer_dest = finetuned_model_dir / "tokenizer"
#     if tokenizer_dest.exists():
#         shutil.rmtree(tokenizer_dest)
#     shutil.copytree(tokenizer_source, tokenizer_dest)
#     print(f"✓ Tokenizer files copied to {tokenizer_dest}")

#     print("\n✓ Fine-tuned model checkpoint saved successfully!")

# # Synchronize all ranks before continuing
# if ddp:
#     torch.distributed.barrier()

# %% [markdown]
# ## Save Fine-Tuned Model (After Training)

# %%
# Save the fine-tuned model after training completes
import shutil
from pathlib import Path

# Create directory for the fine-tuned model
finetuned_model_dir = Path("finetuned_model_checkpoint")
finetuned_model_dir.mkdir(exist_ok=True)

# Save model state
save_path = finetuned_model_dir / "model_finetuned.pt"
meta_path = finetuned_model_dir / "meta_finetuned.json"

torch.save(model.state_dict(), save_path)
print(f"✓ Fine-tuned model saved to {save_path}")

# Save metadata with training info
meta_with_training = meta.copy()
meta_with_training['training_info'] = {
    'num_train_samples': len(train_dataset),
    'num_val_samples': len(val_dataset),
    'num_epochs': num_epochs,
    'effective_batch_size': target_examples_per_step,
    'final_val_loss': val_loss,
}

# If the model is wrapped in DataParallel, save the underlying model
model_to_save = model.module if isinstance(model, torch.nn.DataParallel) else model
torch.save(model_to_save.state_dict(), save_path)

with open(meta_path, "w", encoding="utf-8") as f:
    json.dump(meta_with_training, f, indent=2)
print(f"✓ Metadata saved to {meta_path}")

# Copy tokenizer files
tokenizer_source = base_cache / "tokenizer"
tokenizer_dest = finetuned_model_dir / "tokenizer"
if tokenizer_dest.exists():
    shutil.rmtree(tokenizer_dest)
shutil.copytree(tokenizer_source, tokenizer_dest)
print(f"✓ Tokenizer files copied to {tokenizer_dest}")

print("\n✓ Fine-tuned model checkpoint saved successfully!")
# Out:
# ✓ Fine-tuned model saved to finetuned_model_checkpoint/model_finetuned.pt
# ✓ Metadata saved to finetuned_model_checkpoint/meta_finetuned.json
# ✓ Tokenizer files copied to finetuned_model_checkpoint/tokenizer
#
# ✓ Fine-tuned model checkpoint saved successfully!

# %% [markdown]
# ## Add file to the Colab local foler as zip for transfer to attached Google drive

# %%
# from google.colab import drive
# drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# NotImplementedError                       Traceback (most recent call last)
# /tmp/ipykernel_48/1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.11/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     116   """Internal helper to mount Google Drive."""
#     117   if not _os.path.exists('/var/colab/hostname'):
# --> 118     raise NotImplementedError(
#     119         'Mounting drive is unsupported in this environment. Use PyDrive2'
#     120         ' instead. See examples at'
#
# NotImplementedError: Mounting drive is unsupported in this environment. Use PyDrive2 instead. See examples at https://colab.research.google.com/notebooks/io.ipynb#scrollTo=7taylj9wpsA2.

# %%
import zipfile
import os
import shutil
from pathlib import Path

print("Libraries imported successfully.")
# Out:
# Libraries imported successfully.

# %%
# folder_to_archive = Path("/content/finetuned_model_checkpoint")
# output_zip_name = "finetuned_model_checkpoint.zip"

# print(f"Preparing to archive: {folder_to_archive} into {output_zip_name}")

# %%
# if folder_to_archive.exists():
#     with zipfile.ZipFile(output_zip_name, 'w', zipfile.ZIP_DEFLATED) as zipf:
#         for root, dirs, files in os.walk(folder_to_archive):
#             for file in files:
#                 file_path = os.path.join(root, file)
#                 # Add file to zip, preserving directory structure
#                 zipf.write(file_path, arcname=Path(file_path).relative_to(folder_to_archive.parent))
#     print(f"Successfully created {output_zip_name}")
# else:
#     print(f"Error: Folder '{folder_to_archive}' not found.")

# %%
# # Mount Google Drive if not already mounted (it seems it's already mounted from previous cells)
# # from google.colab import drive
# # drive.mount('/content/drive')

# # Define the destination path in Google Drive
# drive_destination = Path("/content/drive/MyDrive") / output_zip_name

# if Path(output_zip_name).exists():
#     shutil.move(output_zip_name, drive_destination)
#     print(f"Successfully moved {output_zip_name} to {drive_destination}")
#     print("You can now find this file in your Google Drive and download it.")
# else:
#     print(f"Error: Zip file '{output_zip_name}' not found. Please check previous steps.")

# %%
import shutil
from IPython.display import FileLink

# Define the path to the folder you want to download
folder_to_zip = '/kaggle/working/finetuned_model_checkpoint'

# Define the name for the output zip file (it will be saved in /kaggle/working/)
output_zip_filename = 'finetuned_model_checkpoint'

# --- 1. Create the zip archive ---
print(f"Zipping the folder: {folder_to_zip}...")
shutil.make_archive(output_zip_filename, 'zip', folder_to_zip)
print(f"Successfully created {output_zip_filename}.zip in /kaggle/working/")

# --- 2. Create and display a download link for the zip file ---
print("\nClick the link below to download your file:")
display(FileLink(f'{output_zip_filename}.zip'))
# Out:
# Zipping the folder: /kaggle/working/finetuned_model_checkpoint...
# Successfully created finetuned_model_checkpoint.zip in /kaggle/working/
#
# Click the link below to download your file:
# /kaggle/working/finetuned_model_checkpoint.zip

# %% [markdown]
# ### How to download the file from Google Drive:
#
# 1. Go to your Google Drive (drive.google.com).
# 2. Look for the file named `finetuned_model_checkpoint.zip` in your 'My Drive' folder.
# 3. Right-click on the file and select 'Download'.

# %% [markdown]
# ## Load Fine-Tuned Model for Evaluation

# %%
# Load the fine-tuned model for evaluation
finetuned_model_dir = Path("finetuned_model_checkpoint")

# Load fine-tuned model
finetuned_checkpoint_path = finetuned_model_dir / "model_finetuned.pt"
finetuned_meta_path = finetuned_model_dir / "meta_finetuned.json"

# Load metadata
with open(finetuned_meta_path, "r", encoding="utf-8") as f:
    finetuned_meta = json.load(f)

# Create model with same config
finetuned_gptconf = GPTConfig(**finetuned_meta['model_config'])
finetuned_model = GPT(finetuned_gptconf)

# Load state dict
finetuned_state_dict = torch.load(finetuned_checkpoint_path, map_location=device)

# Fix keys if needed (remove '_orig_mod.' prefix)
unwanted_prefix = '_orig_mod.'
for k, v in list(finetuned_state_dict.items()):
    if k.startswith(unwanted_prefix):
        finetuned_state_dict[k[len(unwanted_prefix):]] = finetuned_state_dict.pop(k)

finetuned_model.load_state_dict(finetuned_state_dict)
finetuned_model.eval()  # Set to evaluation mode
finetuned_model.to(device)

print(f"✓ Fine-tuned model loaded successfully!")
print(f"  Model is on device: {device}")
print(f"  Model parameters: {sum(p.numel() for p in finetuned_model.parameters()) / 1e6:.0f}M")

# Initialize tokenizer for fine-tuned model (same as base)
finetuned_tokenizer_dir = finetuned_model_dir / "tokenizer"
finetuned_tokenizer = RustBPETokenizer.from_directory(str(finetuned_tokenizer_dir))
print(f"✓ Fine-tuned model tokenizer loaded")
# Out:
# ✓ Fine-tuned model loaded successfully!
#   Model is on device: cuda
#   Model parameters: 561M
# ✓ Fine-tuned model tokenizer loaded

# %% [markdown]
# ## Evaluation: Generate Responses on Test Set
#
# We'll evaluate both the base model and fine-tuned model on the test set.

# %%
# Load the original base model (unmodified 650-step checkpoint)
base_model_eval, base_tokenizer_eval, _ = build_model(
    checkpoint_dir=str(base_cache / "chatsft_checkpoints" / "d20"),
    step=checkpoint_step,
    device=device,
    phase="eval",
)
print("✓ Original base checkpoint reloaded for comparison.")
# Out:
# 2025-11-24 04:16:45,488 - nanochat.checkpoint_manager - INFO - Building model with config: {'sequence_len': 2048, 'vocab_size': 65536, 'n_layer': 20, 'n_head': 10, 'n_kv_head': 10, 'n_embd': 1280}
# ✓ Original base checkpoint reloaded for comparison.

# %%
# Helper function to generate response using nanochat's generation
def generate_response_with_model(model_instance, tokenizer_instance, conversation, max_tokens=256, temperature=0.7, top_k=50):
    """Generate response using nanochat's native generation"""
    # Precompute special token IDs for this tokenizer
    assistant_end = tokenizer_instance.encode_special("<|assistant_end|>")

    # Build completion prompt
    conversation_for_completion = json.loads(json.dumps(conversation))  # deep copy
    conversation_for_completion["messages"][-1]["content"] = ""
    prompt_tokens = tokenizer_instance.render_for_completion(conversation_for_completion)

    # Generate
    tokens = list(prompt_tokens)
    generated = []

    # Activate autocast context for inference to match model's bfloat16 dtype
    with autocast_ctx:
        for token in model_instance.generate(tokens, max_tokens=max_tokens, temperature=temperature, top_k=top_k):
            tokens.append(token)
            generated.append(token)
            if token == assistant_end:
                break

    # Decode
    text = tokenizer_instance.decode([token for token in generated if token not in {assistant_end}])
    return text.strip(), generated


# Evaluate on test set (use a subset for speed)
EVAL_SIZE = 50  # Adjust as needed

print(f"Generating responses for {EVAL_SIZE} test examples...")
print("This may take a few minutes...\n")

evaluation_results = []

for idx in range(min(EVAL_SIZE, len(conversations))):
    example = conversations[idx]
    convo = example["conversation"]

    # # Generate with base model
    # base_response, _ = generate_response_with_model(model, tokenizer, convo, max_tokens=256, temperature=0.7, top_k=50)
    # Generate with original base checkpoint (clean 650-step)
    base_response, _ = generate_response_with_model(base_model_eval, base_tokenizer_eval, convo, max_tokens=256, temperature=0.7, top_k=50)

    # Generate with fine-tuned model
    finetuned_response, _ = generate_response_with_model(finetuned_model, finetuned_tokenizer, convo, max_tokens=256, temperature=0.7, top_k=50)

    evaluation_results.append({
        "index": idx,
        "example_id": example.get("id"),
        "question": convo["messages"][1]["content"],
        "expected": example["expected_response"],
        "base_response": base_response,
        "finetuned_response": finetuned_response,
    })

    if (idx + 1) % 10 == 0:
        print(f"  Progress: {idx + 1}/{EVAL_SIZE} examples completed")

print(f"\n✓ Generated responses for {len(evaluation_results)} examples")
# Out:
# Generating responses for 50 test examples...
# This may take a few minutes...
#
#   Progress: 10/50 examples completed
#   Progress: 20/50 examples completed
#   Progress: 30/50 examples completed
#   Progress: 40/50 examples completed
#   Progress: 50/50 examples completed
#
# ✓ Generated responses for 50 examples

# %% [markdown]
# ## Compute Accuracy Metrics
#
# Extract answer choices and compute accuracy for both models.

# %%
def extract_choice_letter(text):
    """Extract the answer choice letter (A, B, C, D, E, F) from text"""
    import re

    # Look for patterns like "The correct answer is A" or "A." or "answer: A"
    patterns = [
        r'\b([A-F])\.',  # A. or B. etc
        r'answer is ([A-F])\b',  # answer is A
        r'correct answer is ([A-F])\b',  # correct answer is A
        r'\b([A-F])\b',  # Just the letter A, B, etc
    ]

    for pattern in patterns:
        match = re.search(pattern, text, re.IGNORECASE)
        if match:
            return match.group(1).upper()

    return None


def compute_accuracy_for_model(results, response_key):
    """Compute accuracy given evaluation results and response key"""
    correct = 0
    total = 0
    correct_examples = []
    incorrect_examples = []

    for entry in results:
        expected_letter = extract_choice_letter(entry["expected"])
        predicted_letter = extract_choice_letter(entry[response_key])

        if expected_letter and predicted_letter:
            total += 1
            if expected_letter == predicted_letter:
                correct += 1
                correct_examples.append(entry)
            else:
                incorrect_examples.append({
                    **entry,
                    'expected_letter': expected_letter,
                    'predicted_letter': predicted_letter
                })

    accuracy = correct / total if total else 0.0
    return {
        "evaluated": len(results),
        "scored": total,
        "correct": correct,
        "accuracy": accuracy,
        "correct_examples": correct_examples,
        "incorrect_examples": incorrect_examples,
    }


# Compute metrics for both models
print("Computing accuracy metrics...\n")

base_metrics = compute_accuracy_for_model(evaluation_results, "base_response")
finetuned_metrics = compute_accuracy_for_model(evaluation_results, "finetuned_response")

print("="*80)
print("EVALUATION RESULTS")
print("="*80)
print(f"\nBase Model Performance:")
print(f"  Evaluated: {base_metrics['evaluated']} examples")
print(f"  Scored: {base_metrics['scored']} examples (had parseable answers)")
print(f"  Correct: {base_metrics['correct']} examples")
print(f"  Accuracy: {base_metrics['accuracy']:.2%}")

print(f"\nFine-Tuned Model Performance:")
print(f"  Evaluated: {finetuned_metrics['evaluated']} examples")
print(f"  Scored: {finetuned_metrics['scored']} examples (had parseable answers)")
print(f"  Correct: {finetuned_metrics['correct']} examples")
print(f"  Accuracy: {finetuned_metrics['accuracy']:.2%}")

improvement = finetuned_metrics['accuracy'] - base_metrics['accuracy']
print(f"\n{'='*80}")
print(f"IMPROVEMENT: {improvement:+.2%}")
print(f"{'='*80}")

# Save results to JSON
results_summary = {
    "evaluation_size": len(evaluation_results),
    "base_model": {
        "accuracy": base_metrics['accuracy'],
        "correct": base_metrics['correct'],
        "total_scored": base_metrics['scored'],
    },
    "finetuned_model": {
        "accuracy": finetuned_metrics['accuracy'],
        "correct": finetuned_metrics['correct'],
        "total_scored": finetuned_metrics['scored'],
    },
    "improvement": improvement,
}

with open("evaluation_summary.json", "w") as f:
    json.dump(results_summary, f, indent=2)

print("\n✓ Evaluation summary saved to evaluation_summary.json")
# Out:
# Computing accuracy metrics...
#
# ================================================================================
# EVALUATION RESULTS
# ================================================================================
#
# Base Model Performance:
#   Evaluated: 50 examples
#   Scored: 41 examples (had parseable answers)
#   Correct: 21 examples
#   Accuracy: 51.22%
#
# Fine-Tuned Model Performance:
#   Evaluated: 50 examples
#   Scored: 50 examples (had parseable answers)
#   Correct: 17 examples
#   Accuracy: 34.00%
#
# ================================================================================
# IMPROVEMENT: -17.22%
# ================================================================================
#
# ✓ Evaluation summary saved to evaluation_summary.json

# %% [markdown]
# ## Qualitative Comparison: Side-by-Side Examples
#
# Let's examine some specific examples to see how the models differ in their responses.

# %%
def display_comparison(example):
    """Display side-by-side comparison of base and fine-tuned responses"""
    print("="*100)
    print(f"EXAMPLE {example['index']}")
    print("="*100)

    print("\n📝 QUESTION:")
    print("-" * 100)
    print(example['question'])

    print("\n✅ EXPECTED ANSWER:")
    print("-" * 100)
    print(example['expected'])

    print("\n🤖 BASE MODEL RESPONSE:")
    print("-" * 100)
    print(example['base_response'])

    print("\n🎯 FINE-TUNED MODEL RESPONSE:")
    print("-" * 100)
    print(example['finetuned_response'])
    print("\n" + "="*100 + "\n")


# Display a few interesting examples
print("Showing some example comparisons:\n")

# Show first 3 examples
for i in range(min(3, len(evaluation_results))):
    display_comparison(evaluation_results[i])

# Show some examples where models differ (if available)
print("\n\n" + "="*100)
print("EXAMPLES WHERE MODELS GAVE DIFFERENT ANSWERS")
print("="*100 + "\n")

different_answer_count = 0
for result in evaluation_results:
    base_letter = extract_choice_letter(result['base_response'])
    ft_letter = extract_choice_letter(result['finetuned_response'])

    if base_letter and ft_letter and base_letter != ft_letter:
        display_comparison(result)
        different_answer_count += 1

        if different_answer_count >= 3:  # Show max 3 examples
            break

if different_answer_count == 0:
    print("No examples found where models gave different answers.")
# Out:
# Showing some example comparisons:
#
# ====================================================================================================
# EXAMPLE 0
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# What is the name of the colony shown?
#
# A. Georgia
# B. New Hampshire
# C. South Carolina
# D. West Virginia
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. Georgia
#
# Explanation: The colony is Georgia.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The colony shown is called New Hampshire.
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is C. South Carolina
#
# Explanation: The colony is South Carolina.
#
# ====================================================================================================
#
# ====================================================================================================
# EXAMPLE 1
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# Which animal's skin is also adapted for survival in cold places?
#
# A. snowy owl
# B. hairy armadillo
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. snowy owl
#
# Explanation: Look at the picture of the polar bear.
# The polar bear has skin with thick fur on top and a thick layer of fat underneath it. Its skin is adapted for survival in cold places. The polar bear uses its fur and fat to keep warm in cold weather.
# Now look at each animal. Figure out which animal has a similar adaptation.
# The snowy owl has a thick coat of feathers covering its skin. Its skin is adapted for survival in cold places.
# The hairy armadillo has scales covering much of its skin. Its skin is not adapted for survival in cold places.
#
# Background: An adaptation is an inherited trait that helps an organism survive or reproduce. Adaptations can include both body parts and behaviors.
# The color, texture, and covering of an animal's skin are examples of adaptations. Animals' skins can be adapted in different ways. For example, skin with thick fur might help an animal stay warm. Skin with sharp spines might help an animal defend itself against predators.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# Here are several examples of animals' skin that are also adapted for survival in cold places:
#
# 1. Siberian Husky and Huskies: These animals have thick, white fur that traps heat and helps them survive in extremely cold climates. For example, Siberian Huskies can survive in temperatures as low as -60°F (-50°C) in the harshest environments.
#
# 2. Arctic Fox and Arctic Loon: These animals have thick, insulating fur that helps them survive in bitterly cold seas and frigid temperatures. Arctic foxes have a thick layer of fur that helps keep them warm, and they can also move quickly in the snow by walking and using the snowshoe hairs on their paws to keep them warm.
#
# 3. Arctic Mink and Polar Bear: These animals have fur that traps air and helps them stay warm, and their fur is also resistant to snow and ice. The fur on the underside of their feet is also thick, which helps to protect them from the cold.
#
# 4. Furze and Fox: Furze and Fox have thick, insulating fur that helps them survive in extreme cold temperatures. Furze's fur is specially designed to help it insulate itself, allowing it to survive temperatures as low as -30°F (-20°C) in the Arctic.
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. snowy owl
#
# Explanation: Look at the picture of the snowy owl.
# Its skin is adapted for survival in cold places. The snowy owl's skin is white and snowy. It helps the owl stay warm in cold weather. The fur on the owl's skin also helps to keep the owl warm.
#
# Background: An adaptation is an inherited trait that helps an organism survive or reproduce. Adaptations can include both body parts and behaviors.
# The color, texture, and covering of an animal's skin are examples of adaptations. Animals' skins can be adapted in different ways. For example, skin with thick fur might help an animal stay warm. Skin with sharp spines might help an animal defend itself against predators.
#
# ====================================================================================================
#
# ====================================================================================================
# EXAMPLE 2
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# Compare the motion of three ships. Which ship was moving at the highest speed?
#
# A. a ship that moved 100miles south in 10hours
# B. a ship that moved 385miles south in 10hours
# C. a ship that moved 160miles west in 10hours
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is B. a ship that moved 385miles south in 10hours
#
# Explanation: Look at the distance each ship moved and the time it took to move that distance. The direction each ship moved does not affect its speed.
# Notice that each ship moved for 10 hours. The ship that moved 385 miles moved the farthest distance in that time. So, that ship must have moved at the highest speed.
#
# Background: An object's speed tells you how fast the object is moving. Speed depends on both distance and time.
# Distance tells you how far the object has moved. One unit used to measure distance is the mile.
# Time tells you how long the object has spent moving. One unit used to measure time is the hour.
# Think about objects moving for the same amount of time. The object that is moving the fastest will go the farthest distance in that time. It is moving at the highest speed.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# Here are the explanations:
#
# **Ship A (100miles)**
#
# Ship A had a speed of 100miles per hour. It moved 100miles south in 10 hours. Therefore, its speed was 100miles / 10 hours = 10miles per hour.
#
# **Ship B (385miles)**
#
# Ship B moved 385miles south in 10 hours. Its speed was 385miles / 10 hours = 385miles per hour.
#
# **Ship C (160miles)**
#
# Ship C moved 160miles west in 10 hours. Its speed was 160miles / 10 hours = 160miles per hour.
#
# Now, let's compare the three ships:
#
# 1. Ship A (100miles) vs. Ship B (385miles)
#
# Ship A moved 100miles south in 10 hours, while Ship B moved 385miles south in 10 hours. This means that Ship A moved 100miles south faster than Ship B.
#
# 2. Ship A (100miles) vs. Ship C (160
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is C. a ship that moved 160miles west in 10hours
#
# Explanation: Look at the distance each ship moved and the time it took to move that distance. Then compare the times of the three ships.
# Ship A moved 10 hours, so its distance moved was 10 hours / 10 hours = 1 mile. Ship B moved 10 miles, so its distance moved was 10 miles / 10 miles = 1 mile. The ships were moving at the same speed.
# Ship C moved 160 miles, so its distance moved was 160 miles / 10 hours = 1 mile. The ships were moving at the same speed.
# Notice that the times are the same: 1 minute for each ship. This is because the distance moved is the same for all three ships.
#
# ====================================================================================================
#
#
#
# ====================================================================================================
# EXAMPLES WHERE MODELS GAVE DIFFERENT ANSWERS
# ====================================================================================================
#
# ====================================================================================================
# EXAMPLE 1
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# Which animal's skin is also adapted for survival in cold places?
#
# A. snowy owl
# B. hairy armadillo
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. snowy owl
#
# Explanation: Look at the picture of the polar bear.
# The polar bear has skin with thick fur on top and a thick layer of fat underneath it. Its skin is adapted for survival in cold places. The polar bear uses its fur and fat to keep warm in cold weather.
# Now look at each animal. Figure out which animal has a similar adaptation.
# The snowy owl has a thick coat of feathers covering its skin. Its skin is adapted for survival in cold places.
# The hairy armadillo has scales covering much of its skin. Its skin is not adapted for survival in cold places.
#
# Background: An adaptation is an inherited trait that helps an organism survive or reproduce. Adaptations can include both body parts and behaviors.
# The color, texture, and covering of an animal's skin are examples of adaptations. Animals' skins can be adapted in different ways. For example, skin with thick fur might help an animal stay warm. Skin with sharp spines might help an animal defend itself against predators.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# Here are several examples of animals' skin that are also adapted for survival in cold places:
#
# 1. Siberian Husky and Huskies: These animals have thick, white fur that traps heat and helps them survive in extremely cold climates. For example, Siberian Huskies can survive in temperatures as low as -60°F (-50°C) in the harshest environments.
#
# 2. Arctic Fox and Arctic Loon: These animals have thick, insulating fur that helps them survive in bitterly cold seas and frigid temperatures. Arctic foxes have a thick layer of fur that helps keep them warm, and they can also move quickly in the snow by walking and using the snowshoe hairs on their paws to keep them warm.
#
# 3. Arctic Mink and Polar Bear: These animals have fur that traps air and helps them stay warm, and their fur is also resistant to snow and ice. The fur on the underside of their feet is also thick, which helps to protect them from the cold.
#
# 4. Furze and Fox: Furze and Fox have thick, insulating fur that helps them survive in extreme cold temperatures. Furze's fur is specially designed to help it insulate itself, allowing it to survive temperatures as low as -30°F (-20°C) in the Arctic.
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. snowy owl
#
# Explanation: Look at the picture of the snowy owl.
# Its skin is adapted for survival in cold places. The snowy owl's skin is white and snowy. It helps the owl stay warm in cold weather. The fur on the owl's skin also helps to keep the owl warm.
#
# Background: An adaptation is an inherited trait that helps an organism survive or reproduce. Adaptations can include both body parts and behaviors.
# The color, texture, and covering of an animal's skin are examples of adaptations. Animals' skins can be adapted in different ways. For example, skin with thick fur might help an animal stay warm. Skin with sharp spines might help an animal defend itself against predators.
#
# ====================================================================================================
#
# ====================================================================================================
# EXAMPLE 2
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# Compare the motion of three ships. Which ship was moving at the highest speed?
#
# A. a ship that moved 100miles south in 10hours
# B. a ship that moved 385miles south in 10hours
# C. a ship that moved 160miles west in 10hours
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is B. a ship that moved 385miles south in 10hours
#
# Explanation: Look at the distance each ship moved and the time it took to move that distance. The direction each ship moved does not affect its speed.
# Notice that each ship moved for 10 hours. The ship that moved 385 miles moved the farthest distance in that time. So, that ship must have moved at the highest speed.
#
# Background: An object's speed tells you how fast the object is moving. Speed depends on both distance and time.
# Distance tells you how far the object has moved. One unit used to measure distance is the mile.
# Time tells you how long the object has spent moving. One unit used to measure time is the hour.
# Think about objects moving for the same amount of time. The object that is moving the fastest will go the farthest distance in that time. It is moving at the highest speed.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# Here are the explanations:
#
# **Ship A (100miles)**
#
# Ship A had a speed of 100miles per hour. It moved 100miles south in 10 hours. Therefore, its speed was 100miles / 10 hours = 10miles per hour.
#
# **Ship B (385miles)**
#
# Ship B moved 385miles south in 10 hours. Its speed was 385miles / 10 hours = 385miles per hour.
#
# **Ship C (160miles)**
#
# Ship C moved 160miles west in 10 hours. Its speed was 160miles / 10 hours = 160miles per hour.
#
# Now, let's compare the three ships:
#
# 1. Ship A (100miles) vs. Ship B (385miles)
#
# Ship A moved 100miles south in 10 hours, while Ship B moved 385miles south in 10 hours. This means that Ship A moved 100miles south faster than Ship B.
#
# 2. Ship A (100miles) vs. Ship C (160
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is C. a ship that moved 160miles west in 10hours
#
# Explanation: Look at the distance each ship moved and the time it took to move that distance. Then compare the times of the three ships.
# Ship A moved 10 hours, so its distance moved was 10 hours / 10 hours = 1 mile. Ship B moved 10 miles, so its distance moved was 10 miles / 10 miles = 1 mile. The ships were moving at the same speed.
# Ship C moved 160 miles, so its distance moved was 160 miles / 10 hours = 1 mile. The ships were moving at the same speed.
# Notice that the times are the same: 1 minute for each ship. This is because the distance moved is the same for all three ships.
#
# ====================================================================================================
#
# ====================================================================================================
# EXAMPLE 3
# ====================================================================================================
#
# 📝 QUESTION:
# ----------------------------------------------------------------------------------------------------
# Will these magnets attract or repel each other?
#
# A. repel
# B. attract
#
# ✅ EXPECTED ANSWER:
# ----------------------------------------------------------------------------------------------------
# The correct answer is A. repel
#
# Explanation: To predict if these magnets will attract or repel, look at which poles are closest to each other.
# The north pole of one magnet is closest to the north pole of the other magnet. Like poles repel. So, these magnets will repel each other.
#
# Background: Magnets can pull or push on other magnets without touching them. When magnets attract, they pull together. When magnets repel, they push apart. These pulls and pushes are called magnetic forces.
# Magnetic forces are strongest at the magnets' poles, or ends. Every magnet has two poles: a north pole (N) and a south pole (S).
# Here are some examples of magnets. Their poles are shown in different colors and labeled.
# Whether a magnet attracts or repels other magnets depends on the positions of its poles.
# If opposite poles are closest to each other, the magnets attract. The magnets in the pair below attract.
# If the same, or like, poles are closest to each other, the magnets repel. The magnets in both pairs below repel.
#
# 🤖 BASE MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# Here are the explanations:
#
# 1. **Antennas**: Antennas are small structures that can be used to transmit signals, such as radio waves. They allow signals to be received and decoded by receivers. Antennas are usually made of two or more metal poles, usually made of copper, and are typically spaced apart by a distance of about 50-100 feet.
#
# 2. **Magnets**: Magnets attract each other because they use magnets to attract each other. They have magnetic poles, which are loops of magnetic material that have opposite poles. When a magnet touches a metal surface, it creates a magnetic field that the surface can attract. This attraction is what makes magnets attract other magnets and other magnetic materials.
#
# 3. **Conduction vs. Convection**: Conduction and convection are two processes that happen when a magnetic field is applied. Conduction is like a current that flows through metal, where the magnetic field creates a force. This force pushes the metal apart, creating a gap between the metal and the magnet. Convection is like a fluid that flows through the metal, where the magnetic field pushes the fluid into a smaller gap.
#
# 4. **Magnets and Copper**: Copper is a metal that attracts magnets because
#
# 🎯 FINE-TUNED MODEL RESPONSE:
# ----------------------------------------------------------------------------------------------------
# The correct answer is B. attract
#
# Explanation: To predict if these magnets will attract or repel, look at which poles are closest to each other.
# The south pole of one magnet is closest to the south pole of the other magnet. Like poles repel. So, these magnets will repel each other.
#
# Background: Magnets can pull or push on each other without touching. When magnets attract, they pull together. When magnets repel, they push apart.
# Whether a magnet attracts or repels other magnets depends on the positions of its poles, or ends. Every magnet has two poles: north and south.
# Here are some examples of magnets. The north pole of each magnet is marked N, and the south pole is marked S.
# If different poles are closest to each other, the magnets attract. The magnets in the pair below attract.
# If the same poles are closest to each other, the magnets repel. The magnets in both pairs below repel.
#
# ====================================================================================================

# %% [markdown]
# ## Interactive Demo: Science Tutor Assistant
#
# Test the fine-tuned model interactively with your own questions.

# %%
def test_single_question(question_text, use_finetuned=True):
    """Test a single question with either base or fine-tuned model"""

    # Create conversation format
    test_conversation = {
        "messages": [
            {"role": "system", "content": "You are a helpful science tutor for elementary through high school students. Explain concepts clearly with examples."},
            {"role": "user", "content": question_text},
            {"role": "assistant", "content": ""}
        ]
    }

    # Select model and tokenizer
    if use_finetuned:
        selected_model = finetuned_model
        selected_tokenizer = finetuned_tokenizer
        model_name = "Fine-Tuned Model"
    else:
        selected_model = base_model_eval
        selected_tokenizer = base_tokenizer_eval
        model_name = "Base Model"

    # Generate response
    response, _ = generate_response_with_model(
        selected_model,
        selected_tokenizer,
        test_conversation,
        max_tokens=300,
        temperature=0.7,
        top_k=50
    )

    print("="*100)
    print(f"🤖 {model_name.upper()}")
    print("="*100)
    print("\n📝 QUESTION:")
    print(question_text)
    print(f"\n💬 {model_name.upper()} RESPONSE:")
    print(response)
    print("="*100 + "\n")

    return response


# Test with sample science questions
print("Testing the fine-tuned model with sample questions:\n")

sample_questions = [
    """What is photosynthesis?
A. The process plants use to make food from sunlight
B. The process of cell division
C. The process of breathing
D. The process of digestion""",

    """What is the main cause of ocean tides?
A. Wind blowing across the ocean surface
B. The gravitational pull of the Moon
C. Temperature differences in the water
D. Earth's rotation""",

    """Which state of matter has a definite volume but no definite shape?
A. Solid
B. Liquid
C. Gas
D. Plasma"""
]

for i, question in enumerate(sample_questions, 1):
    print(f"\n{'#'*100}")
    print(f"TEST QUESTION {i}")
    print(f"{'#'*100}\n")
    test_single_question(question, use_finetuned=False)
# Out:
# Testing the fine-tuned model with sample questions:
#
#
# ####################################################################################################
# TEST QUESTION 1
# ####################################################################################################
#
# ====================================================================================================
# 🤖 BASE MODEL
# ====================================================================================================
#
# 📝 QUESTION:
# What is photosynthesis?
# A. The process plants use to make food from sunlight
# B. The process of cell division
# C. The process of breathing
# D. The process of digestion
#
# 💬 BASE MODEL RESPONSE:
# Here are the explanations:
#
# **Photosynthesis (Para. 1):**
# Photosynthesis is the process by which plants, algae, and certain bacteria convert sunlight, water, and carbon dioxide into glucose and oxygen. This process occurs in the cells of plants, algae, and some bacteria. During photosynthesis, the green pigment chlorophyll absorbs light energy, which excites electrons. The electrons are then used to reduce NADP+ to NADPH, which is essential for the next stage of photosynthesis. The electrons from NADP+ are used to generate ATP and NADP, which are used to fuel various cellular activities. The overall equation for photosynthesis is: 6 CO2 + 6 H2O + light energy → C6H12O6 + 6 O2 + 6 H2<|user_end|><|assistant_start|>**Photosynthesis (Para. 2):**
# Here's a rewritten version of the explanation:
#
# Photosynthesis is the process by which plants, algae, and some bacteria convert sunlight, water, and carbon dioxide into glucose and oxygen. During this process, the green pigment chlorophyll absorbs light energy, which excites electrons. The electrons are then used to reduce NADP+ to NADPH, which is essential for the next stage of photosynthesis. The electrons from NADP+ are used to generate ATP and NADP, which are used to fuel various cellular activities. The overall equation for photosynthesis is: 6 CO2 + 6 H2O + light energy → C6H12
# ====================================================================================================
#
#
# ####################################################################################################
# TEST QUESTION 2
# ####################################################################################################
#
# ====================================================================================================
# 🤖 BASE MODEL
# ====================================================================================================
#
# 📝 QUESTION:
# What is the main cause of ocean tides?
# A. Wind blowing across the ocean surface
# B. The gravitational pull of the Moon
# C. Temperature differences in the water
# D. Earth's rotation
#
# 💬 BASE MODEL RESPONSE:
# The main cause of ocean tides is the gravitational pull of the Moon. The gravitational pull of the Moon causes the water in the ocean to bulge outward from the center towards the Moon. As the Moon moves around the Earth, it causes the water to move in different directions, creating the resulting force that causes the tides to rise and fall.
# ====================================================================================================
#
#
# ####################################################################################################
# TEST QUESTION 3
# ####################################################################################################
#
# ====================================================================================================
# 🤖 BASE MODEL
# ====================================================================================================
#
# 📝 QUESTION:
# Which state of matter has a definite volume but no definite shape?
# A. Solid
# B. Liquid
# C. Gas
# D. Plasma
#
# 💬 BASE MODEL RESPONSE:
# Here are several examples of situations where students can use the definite volume of a substance but no definite shape:
#
# **States of Matter:**
#
# * The volume of a solid is determined by its mass and density.
# * The volume of a liquid is determined by its temperature and pressure.
# * The volume of a gas is determined by its volume and volume of its surroundings.
# * The volume of a substance is determined by its density and size.
#
# **States of Matter:**
#
# * The volume of a liquid is determined by its temperature and pressure.
# * The volume of a gas is determined by its volume and volume of its surroundings.
# * The volume of a substance is determined by its temperature and pressure.
#
# **States of Matter:**
#
# * The volume of a gas is determined by its volume and volume of its surroundings.
# * The volume of a liquid is determined by its volume and volume of its surroundings.
# * The volume of a substance is determined by its temperature and pressure.
# ====================================================================================================

# %% [markdown]
# ## Optional: Gradio Web Interface
#
# Uncomment the cell below to launch an interactive web interface for your Science Tutor. This creates a shareable demo with a chat-like interface.

# %%
# # OPTIONAL: Gradio Web Interface
# # Uncomment this cell to launch an interactive web demo

# # Install gradio if not already installed
# # !pip install -q gradio

# import gradio as gr

# def respond_to_question(message, chat_history, use_finetuned_checkbox):
#     """Generate response for Gradio interface"""

#     # Create conversation format
#     conversation = {
#         "messages": [
#             {"role": "system", "content": "You are a helpful science tutor for elementary through high school students. Explain concepts clearly with examples."},
#             {"role": "user", "content": message},
#             {"role": "assistant", "content": ""}
#         ]
#     }

#     # Select model based on checkbox
#     if use_finetuned_checkbox:
#         selected_model = finetuned_model
#         selected_tokenizer = finetuned_tokenizer
#     else:
#         selected_model = model
#         selected_tokenizer = tokenizer

#     # Generate response
#     response, _ = generate_response_with_model(
#         selected_model,
#         selected_tokenizer,
#         conversation,
#         max_tokens=300,
#         temperature=0.7,
#         top_k=50
#     )

#     chat_history.append((message, response))
#     return "", chat_history


# # Create Gradio interface
# with gr.Blocks(title="Science Tutor Assistant") as demo:
#     gr.Markdown("# 🔬 Science Tutor Assistant")
#     gr.Markdown("### Ask me any science question from Biology, Chemistry, Physics, or Earth Science!")
#     gr.Markdown("*Powered by nanochat fine-tuned on ScienceQA dataset*")

#     with gr.Row():
#         use_finetuned = gr.Checkbox(label="Use Fine-Tuned Model", value=True,
#                                     info="Uncheck to use base model for comparison")

#     chatbot = gr.Chatbot(label="Science Tutor", height=400)

#     with gr.Row():
#         msg = gr.Textbox(
#             label="Your Question",
#             placeholder="Type your science question here... (e.g., What is photosynthesis?)",
#             lines=3,
#             scale=4
#         )
#         submit = gr.Button("Ask", scale=1, variant="primary")

#     clear = gr.Button("Clear Chat")

#     # Example questions
#     gr.Examples(
#         examples=[
#             "What is photosynthesis?",
#             "Explain Newton's first law of motion",
#             "What causes ocean tides?",
#             "What are the three states of matter?",
#             "How does the water cycle work?",
#             "What is cellular respiration?"
#         ],
#         inputs=msg,
#         label="Example Questions"
#     )

#     # Event handlers
#     msg.submit(respond_to_question, [msg, chatbot, use_finetuned], [msg, chatbot])
#     submit.click(respond_to_question, [msg, chatbot, use_finetuned], [msg, chatbot])
#     clear.click(lambda: None, None, chatbot, queue=False)

# # Launch the interface
# # share=True creates a public link you can share with others
# print("Launching Gradio interface...")
# demo.launch(share=True, server_port=7860)

# %% [markdown]
# ## 📊 Project Summary & Next Steps
#
# ### ✅ Completed Tasks
#
# This notebook has completed the following:
#
# 1. **Environment Setup**: Loaded nanochat repository and dependencies
# 2. **Data Preparation**: Loaded and formatted ScienceQA dataset for conversational format
# 3. **Base Model Loading**: Loaded the `sdobson/nanochat` checkpoint
# 4. **Model Training**: Set up training pipeline with nanochat's native functions
# 5. **Model Saving**: Saved fine-tuned model checkpoint
# 6. **Evaluation**: Computed accuracy metrics for base vs fine-tuned models
# 7. **Qualitative Analysis**: Compared responses side-by-side
# 8. **Interactive Demo**: Created testing functions and optional web interface
#
# ### 📁 Generated Files
#
# - `finetuned_model_checkpoint/`: Directory containing fine-tuned model
#   - `model_finetuned.pt`: Model weights
#   - `meta_finetuned.json`: Model metadata and training info
#   - `tokenizer/`: Tokenizer files
# - `evaluation_summary.json`: Quantitative evaluation results
# - `data/`: Formatted datasets (train, validation, test)
#
# ### 🎯 Key Results
#
# Check the evaluation cells above for:
# - Base model accuracy
# - Fine-tuned model accuracy
# - Improvement percentage
# - Example comparisons
#
# ### 🚀 Next Steps
#
# 1. **For Testing (No GPU)**:
#    - Uncomment the "TESTING OPTION" cell to save base model as pseudo fine-tuned
#    - Run evaluation cells to validate pipeline
#    - Test with sample questions
#
# 2. **For Training (With GPU on Kaggle/Colab)**:
#    - Run the training cell (it will take 2-4 hours)
#    - Monitor GPU memory usage
#    - Save checkpoints regularly
#    - Compare before/after results
#
# 3. **For Deployment**:
#    - Upload model to HuggingFace Hub
#    - Launch Gradio interface for public demo
#    - Share results with stakeholders
#
# ### 📚 Notes
#
# - **Memory Management**: If you encounter OOM errors, reduce `device_batch_size` or move model to CPU
# - **Evaluation Size**: Adjust `EVAL_SIZE` based on available time/resources
# - **Generation Parameters**: Modify `temperature`, `top_k`, `max_tokens` for different response styles
# - **Training Duration**: Full training on 3000 samples takes approximately 2-4 hours on a consumer GPU
#
# ### 🔗 Resources
#
# - Nanochat Repository: https://github.com/karpathy/nanochat
# - ScienceQA Dataset: https://huggingface.co/datasets/derek-thomas/ScienceQA
# - Model Checkpoint: https://huggingface.co/sdobson/nanochat
#
# ---
#
# **Project Status**: All components implemented and ready for testing/training!

# %% [markdown]
# ## 🧪 Test Your Own Questions
#
# Use the cell below to test your own science questions!

# %%
# # Test your own question here!
# # Modify the question below and run this cell

# your_question = """What is the difference between weather and climate?
# A. Weather is short-term, climate is long-term patterns
# B. Weather is warm, climate is cold
# C. Weather happens on land, climate happens in the ocean
# D. They are the same thing"""

# print("Testing with your custom question:\n")
# print("="*100)
# print("COMPARING BOTH MODELS")
# print("="*100 + "\n")

# # Test with base model
# print("🤖 BASE MODEL:")
# print("-"*100)
# test_single_question(your_question, use_finetuned=False)

# print("\n")

# # Test with fine-tuned model
# print("🎯 FINE-TUNED MODEL:")
# print("-"*100)
# test_single_question(your_question, use_finetuned=True)

# print("\n" + "="*100)
# print("✅ Test complete! Modify 'your_question' above to test other questions.")
# print("="*100)

# %%
# Additional code or experiments can be added here

# %%
# import time
# from contextlib import nullcontext
# from nanochat.common import autodetect_device_type

# device_type = "gpu"
# autocast_ctx = torch.amp.autocast(device_type=device_type, dtype=ptdtype) if device_type == "cuda" else nullcontext()

# # Learning rate scheduler
# def get_lr_multiplier(it):
#     lrm = 1.0 - it / num_iterations
#     return lrm

# print("Starting fine-tuning...")
# train_iter = iter(train_loader)
# val_iter = iter(val_loader)
# val_loss = 0.0
# step_time_ema = 0.0

# for step in range(num_iterations):
#     t0 = time.time()
#     last_step = step == num_iterations - 1

#     # Validation loop
#     if last_step or step % eval_every == 0:
#         model.eval()
#         losses = []
#         for _ in range(eval_steps):
#             val_inputs, val_targets = next(val_iter)
#             with torch.no_grad(), autocast_ctx:
#                 loss = model(val_inputs, val_targets)
#             losses.append(loss)
#         val_loss = torch.stack(losses).mean().item()
#         print(f"Step {step:05d} | Validation loss: {val_loss:.6f}")
#         model.train()

#     # Training loop
#     num_tokens = 0
#     for micro_step in range(grad_accum_steps):
#         train_inputs, train_targets = next(train_iter)
#         with autocast_ctx:
#             loss = model(train_inputs, train_targets)
#         train_loss = loss.detach() # for logging
#         loss = loss / grad_accum_steps # each .backward() is a grad sum => normalize loss here
#         loss.backward() # accumulate the gradient
#         num_tokens += (train_targets >= 0).sum()

#     # Update learning rate
#     lrm = get_lr_multiplier(step)
#     for opt in optimizers:
#         for group in opt.param_groups:
#             group["lr"] = group["initial_lr"] * lrm

#     # Step the optimizers
#     for opt in optimizers:
#         opt.step()
#     model.zero_grad(set_to_none=True)

#     # Timing and logging
#     t1 = time.time()
#     dt = t1 - t0
#     step_time_ema = dt if step_time_ema == 0 else 0.9 * step_time_ema + 0.1 * dt
#     tokens_per_sec = num_tokens.item() / dt

#     print(f"Step {step:05d}/{num_iterations:05d} | Train loss: {train_loss.item():.6f} | LR mult: {lrm:.4f} | Tok/s: {tokens_per_sec:,.0f} | Step time: {step_time_ema:.3f}s")

# print("\nTraining complete.")
